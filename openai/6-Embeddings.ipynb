# %% [markdown]
# # Embedding
# ## What is Embedding
# An embedding is a vector (list) of floating point numbers. The distance between two vectors measures their relatedness. Small distances suggest high relatedness and large distances suggest low relatedness.
#
# ## Usage of Embedding
# Embeddings are commonly used for:
#
# - **Search** (where results are ranked by relevance to a query string)
# - **Clustering** (where text strings are grouped by similarity)
# - **Recommendations** (where items with related text strings are recommended)
# - **Anomaly detection** (where outliers with little relatedness are identified)
# - **Diversity measurement** (where similarity distributions are analyzed)
# - **Classification** (where text strings are classified by their most similar label)
#
# ## Embedding models
#
# |MODEL	|~ PAGES PER DOLLAR	|PERFORMANCE ON MTEB EVAL	|MAX INPUT
# |:--------:|:--------:|:--------:|:--------:|
# |text-embedding-3-small|	62,500 |62.3%	|8191|
# |text-embedding-3-large	|9,615  |64.6%	|8191|
# |text-embedding-ada-002	|12,500 |61.0%	|8191|
#
# for more info please refer to this official docs [Embeddings](https://platform.openai.com/docs/guides/embeddings)

# %% [markdown]
# ## Setup

# %%
import os
from dotenv import load_dotenv, find_dotenv
# find_dotenv() find .env automatically by walking up directories until it's found 
# load_dotenv() load the environment variables from the .env file
# override=True allows the .env file to override the system environment variables
load_dotenv(find_dotenv(), override=True)

apiKey = os.environ.get('OPENAI_API_KEY')

# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\mohamed.tawfik\appdata\local\anaconda3\envs\openaienv\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI
from sklearn.metrics.pairwise import cosine_similarity
client = OpenAI(api_key=apiKey)

# %% [markdown]
# ## Getting Embeddings

# %%
cat_embedding = client.embeddings.create(
    model="text-embedding-3-small",
    input="cat",
)

car_embedding = client.embeddings.create(
    model="text-embedding-3-small",
    input="car",
)

dog_embedding =client.embeddings.create(
    model="text-embedding-3-small",
    input="dog",
)

# %%
#print(cat_embedding)
print(car_embedding.data[0].embedding)

# %% [markdown]
# ## Get Similarities Using Embedding

# %% [markdown]
# We need Numpy and Pandas libraries
# To check if libraries are installed use the following command `%pip show LibraryName` to show the version of library if installed or display that library not installed

# %%
import numpy as np
import pandas as pd

# Read the data file
data = pd.read_csv('assets/words.csv')
data
# Out:
#           text
# 0          fox
# 1      opossum
# 2        black
# 3       purple
# 4       badger
# 5       coffee
# 6       rabbit
# 7         hare
# 8         soda
# 9       yellow
# 10  cappuccino
# 11        deer
# 12        bird
# 13     raccoon
# 14     hamster
# 15      burger
# 16      ferret
# 17        wolf
# 18    squirrel
# 19      lizard
# 20         red
# 21        milk
# 22         tea
# 23        blue
# 24    sandwich
# 25      coyote
# 26        fish
# 27         dog
# 28        bear
# 29       salad
# 30       pizza
# 31       snake
# 32       pasta
# 33      turtle
# 34       brown
# 35       white
# 36         cat
# 37  guinea pig
# 38       green
# 39        gray
# 40       water
# 41      orange

# %% [markdown]
# ### Check Pricing
# - Use tiktoken library to get the number of tokens for your data
# - Check (pricing page)[https://openai.com/api/pricing/] to check how much you will pay

# %%
import tiktoken as tkn

# %%
#create list of the data 
words = list(data['text'])
enc = tkn.encoding_for_model(model_name="text-embedding-3-small")
total_tokens = sum([len(enc.encode(word)) for word in words])
print(f"Total tokens: {total_tokens}")
cost = total_tokens * (0.00002/1000)
print(f"Cost: ${cost:.20f}")
# Out:
# Total tokens: 62
# Cost: $0.00000124000000000000

# %%
# Create a function to get the embeddings of a word
def get_embeddings(word):
    embedding = client.embeddings.create(
        model="text-embedding-3-small",
        input=word,
    )    
    return embedding.data[0].embedding

# %% [markdown]
# ### Store the embedding for each word
# - After getting embedding for your data store them in permanent storage to avoid getting embedding every time you want to process a query and save time and money

# %%
data['embedding']= data['text'].apply(lambda x: get_embeddings(x))
data
# Out:
#           text                                          embedding
# 0          fox  [-0.03355345129966736, 0.001505932305008173, -...
# 1      opossum  [0.03196421265602112, 0.03251579403877258, -0....
# 2        black  [0.01116090640425682, -0.012063156813383102, -...
# 3       purple  [0.02472393959760666, -0.034728385508060455, -...
# 4       badger  [0.021644549444317818, -0.022302215918898582, ...
# 5       coffee  [-0.010105200111865997, 0.0037400261498987675,...
# 6       rabbit  [0.006220409180969, -0.015751302242279053, 0.0...
# 7         hare  [0.01832250878214836, -0.0220760777592659, 0.0...
# 8         soda  [0.018451469019055367, -0.025056716054677963, ...
# 9       yellow  [-0.014238273724913597, -0.018038872629404068,...
# 10  cappuccino  [-0.024895260110497475, -0.030884910374879837,...
# 11        deer  [0.060825735330581665, -0.03296774625778198, 0...
# 12        bird  [0.05648331344127655, -0.0011298867175355554, ...
# 13     raccoon  [0.05898168683052063, -0.0009809075854718685, ...
# 14     hamster  [0.03871235251426697, -0.027450142428278923, 0...
# 15      burger  [-0.03550729528069496, -0.01598917506635189, 0...
# 16      ferret  [0.006305847316980362, -0.041793812066316605, ...
# 17        wolf  [-0.0030049828346818686, -0.026660829782485962...
# 18    squirrel  [0.03322089836001396, -0.04075725004076958, -0...
# 19      lizard  [0.012100729160010815, -0.012437433004379272, ...
# 20         red  [-0.022114494815468788, -0.010901302099227905,...
# 21        milk  [0.03963107243180275, -0.00417668791487813, -0...
# 22         tea  [-0.01637290231883526, -0.030905066058039665, ...
# 23        blue  [-0.0011808431008830667, -0.016510002315044403...
# 24    sandwich  [-0.005682190880179405, -0.04893353208899498, ...
# 25      coyote  [0.04016764461994171, -0.031213432550430298, -...
# 26        fish  [-0.002734047593548894, -0.021766602993011475,...
# 27         dog  [0.05113774910569191, -0.01870863139629364, -0...
# 28        bear  [0.04613043740391731, -0.01706441305577755, -0...
# 29       salad  [-0.0006578968022949994, -0.03706714138388634,...
# 30       pizza  [-0.01020066812634468, -0.028279945254325867, ...
# 31       snake  [0.051066912710666656, -0.020128140226006508, ...
# 32       pasta  [-0.05013786256313324, -0.04082654416561127, 0...
# 33      turtle  [0.028160911053419113, -0.016313010826706886, ...
# 34       brown  [-0.030695391818881035, -0.00717085599899292, ...
# 35       white  [0.0032686665654182434, -0.028257660567760468,...
# 36         cat  [0.025529420003294945, -0.023411665111780167, ...
# 37  guinea pig  [0.007524285465478897, -0.026610590517520905, ...
# 38       green  [0.006235065869987011, -0.0011298545869067311,...
# 39        gray  [0.004804749041795731, -0.020221514627337456, ...
# 40       water  [0.0030196786392480135, 0.017477955669164658, ...
# 41      orange  [-0.025900742039084435, -0.005591441877186298,...

# %%
#save the data to a csv file
data.to_csv('assets/words_with_embeddings.csv', index=False)

# %% [markdown]
# ### Perform Semantic Search

# %%
# Read the data file
words_data = pd.read_csv('assets/words_with_embeddings.csv')
#words_data.head()
# Convert the embeddings to a numpy array instead of plain string  
words_data['embedding'] = words_data['embedding'].apply(eval).apply(np.array)
words_data.head()
# Out:
#       text                                          embedding
# 0      fox  [-0.03355345129966736, 0.001505932305008173, -...
# 1  opossum  [0.03196421265602112, 0.03251579403877258, -0....
# 2    black  [0.01116090640425682, -0.012063156813383102, -...
# 3   purple  [0.02472393959760666, -0.034728385508060455, -...
# 4   badger  [0.021644549444317818, -0.022302215918898582, ...

# %% [markdown]
# Use Cosine Similarity algorithm to get the similarities
# you can check [Wikipedia](https://en.wikipedia.org/wiki/Cosine_similarity) for more info

# %%
# %pip install scikit-learn -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Calculate the embedding of the search term
red_embedding = get_embeddings('milk')
words_data['cosine_similarity'] = words_data['embedding'].apply(lambda x: cosine_similarity([red_embedding], [x])[0][0])
words_data
# Out:
#           text                                          embedding  \
# 20         red  [-0.022114494815468788, -0.010901302099227905,...
# 23        blue  [-0.0011808431008830667, -0.016510002315044403...
# 3       purple  [0.02472393959760666, -0.034728385508060455, -...
# 35       white  [0.0032686665654182434, -0.028257660567760468,...
# 41      orange  [-0.025900742039084435, -0.005591441877186298,...
# 11        deer  [0.060825735330581665, -0.03296774625778198, 0...
# 39        gray  [0.004804749041795731, -0.020221514627337456, ...
# 2        black  [0.01116090640425682, -0.012063156813383102, -...
# 34       brown  [-0.030695391818881035, -0.00717085599899292, ...
# 0          fox  [-0.03355345129966736, 0.001505932305008173, -...
# 38       green  [0.006235065869987011, -0.0011298545869067311,...
# 9       yellow  [-0.014238273724913597, -0.018038872629404068,...
# 6       rabbit  [0.006220409180969, -0.015751302242279053, 0.0...
# 7         hare  [0.01832250878214836, -0.0220760777592659, 0.0...
# 28        bear  [0.04613043740391731, -0.01706441305577755, -0...
# 27         dog  [0.05113774910569191, -0.01870863139629364, -0...
# 12        bird  [0.05648331344127655, -0.0011298867175355554, ...
# 17        wolf  [-0.0030049828346818686, -0.026660829782485962...
# 4       badger  [0.021644549444317818, -0.022302215918898582, ...
# 13     raccoon  [0.05898168683052063, -0.0009809075854718685, ...
# 15      burger  [-0.03550729528069496, -0.01598917506635189, 0...
# 16      ferret  [0.006305847316980362, -0.041793812066316605, ...
# 33      turtle  [0.028160911053419113, -0.016313010826706886, ...
# 29       salad  [-0.0006578968022949994, -0.03706714138388634,...
# 22         tea  [-0.01637290231883526, -0.030905066058039665, ...
# 5       coffee  [-0.010105200111865997, 0.0037400261498987675,...
# 19      lizard  [0.012100729160010815, -0.012437433004379272, ...
# 26        fish  [-0.002734047593548894, -0.021766602993011475,...
# 40       water  [0.0030196786392480135, 0.017477955669164658, ...
# 8         soda  [0.018451469019055367, -0.025056716054677963, ...
# 31       snake  [0.051066912710666656, -0.020128140226006508, ...
# 36         cat  [0.025529420003294945, -0.023411665111780167, ...
# 25      coyote  [0.04016764461994171, -0.031213432550430298, -...
# 30       pizza  [-0.01020066812634468, -0.028279945254325867, ...
# 18    squirrel  [0.03322089836001396, -0.04075725004076958, -0...
# 14     hamster  [0.03871235251426697, -0.027450142428278923, 0...
# 32       pasta  [-0.05013786256313324, -0.04082654416561127, 0...
# 21        milk  [0.03963107243180275, -0.00417668791487813, -0...
# 1      opossum  [0.03196421265602112, 0.03251579403877258, -0....
# 24    sandwich  [-0.005682190880179405, -0.04893353208899498, ...
# 37  guinea pig  [0.007524285465478897, -0.026610590517520905, ...
# 10  cappuccino  [-0.024895260110497475, -0.030884910374879837,...
#
#     cosine_similarity
# 20           0.216396
# 23           0.238026
# 3            0.270218
# 35           0.314009
# 41           0.219831
# 11           0.236315
# 39           0.197774
# 2            0.233110
# 34           0.258159
# 0            0.198153
# 38           0.225343
# 9            0.225958
# 6            0.207234
# 7            0.207871
# 28           0.235973
# 27           0.206074
# 12           0.156440
# 17           0.189011
# 4            0.237347
# 13           0.216263
# 15           0.245500
# 16           0.169521
# 33           0.157135
# 29           0.310149
# 22           0.325191
# 5            0.340499
# 19           0.233126
# 26           0.246608
# 40           0.333474
# 8            0.370392
# 31           0.129687
# 36           0.216024
# 25           0.229282
# 30           0.230094
# 18           0.254095
# 14           0.220531
# 32           0.378354
# 21           1.000000
# 1            0.169788
# 24           0.288500
# 37           0.204560
# 10           0.377345

# %%
# Sort the data by cosine similarity
words_data = words_data.sort_values(by='cosine_similarity', ascending=False)
words_data
# Out:
#           text                                          embedding  \
# 21        milk  [0.03963107243180275, -0.00417668791487813, -0...
# 32       pasta  [-0.05013786256313324, -0.04082654416561127, 0...
# 10  cappuccino  [-0.024895260110497475, -0.030884910374879837,...
# 8         soda  [0.018451469019055367, -0.025056716054677963, ...
# 5       coffee  [-0.010105200111865997, 0.0037400261498987675,...
# 40       water  [0.0030196786392480135, 0.017477955669164658, ...
# 22         tea  [-0.01637290231883526, -0.030905066058039665, ...
# 35       white  [0.0032686665654182434, -0.028257660567760468,...
# 29       salad  [-0.0006578968022949994, -0.03706714138388634,...
# 24    sandwich  [-0.005682190880179405, -0.04893353208899498, ...
# 3       purple  [0.02472393959760666, -0.034728385508060455, -...
# 34       brown  [-0.030695391818881035, -0.00717085599899292, ...
# 18    squirrel  [0.03322089836001396, -0.04075725004076958, -0...
# 26        fish  [-0.002734047593548894, -0.021766602993011475,...
# 15      burger  [-0.03550729528069496, -0.01598917506635189, 0...
# 23        blue  [-0.0011808431008830667, -0.016510002315044403...
# 4       badger  [0.021644549444317818, -0.022302215918898582, ...
# 11        deer  [0.060825735330581665, -0.03296774625778198, 0...
# 28        bear  [0.04613043740391731, -0.01706441305577755, -0...
# 19      lizard  [0.012100729160010815, -0.012437433004379272, ...
# 2        black  [0.01116090640425682, -0.012063156813383102, -...
# 30       pizza  [-0.01020066812634468, -0.028279945254325867, ...
# 25      coyote  [0.04016764461994171, -0.031213432550430298, -...
# 9       yellow  [-0.014238273724913597, -0.018038872629404068,...
# 38       green  [0.006235065869987011, -0.0011298545869067311,...
# 14     hamster  [0.03871235251426697, -0.027450142428278923, 0...
# 41      orange  [-0.025900742039084435, -0.005591441877186298,...
# 20         red  [-0.022114494815468788, -0.010901302099227905,...
# 13     raccoon  [0.05898168683052063, -0.0009809075854718685, ...
# 36         cat  [0.025529420003294945, -0.023411665111780167, ...
# 7         hare  [0.01832250878214836, -0.0220760777592659, 0.0...
# 6       rabbit  [0.006220409180969, -0.015751302242279053, 0.0...
# 27         dog  [0.05113774910569191, -0.01870863139629364, -0...
# 37  guinea pig  [0.007524285465478897, -0.026610590517520905, ...
# 0          fox  [-0.03355345129966736, 0.001505932305008173, -...
# 39        gray  [0.004804749041795731, -0.020221514627337456, ...
# 17        wolf  [-0.0030049828346818686, -0.026660829782485962...
# 1      opossum  [0.03196421265602112, 0.03251579403877258, -0....
# 16      ferret  [0.006305847316980362, -0.041793812066316605, ...
# 33      turtle  [0.028160911053419113, -0.016313010826706886, ...
# 12        bird  [0.05648331344127655, -0.0011298867175355554, ...
# 31       snake  [0.051066912710666656, -0.020128140226006508, ...
#
#     cosine_similarity
# 21           1.000000
# 32           0.378354
# 10           0.377345
# 8            0.370392
# 5            0.340499
# 40           0.333474
# 22           0.325191
# 35           0.314009
# 29           0.310149
# 24           0.288500
# 3            0.270218
# 34           0.258159
# 18           0.254095
# 26           0.246608
# 15           0.245500
# 23           0.238026
# 4            0.237347
# 11           0.236315
# 28           0.235973
# 19           0.233126
# 2            0.233110
# 30           0.230094
# 25           0.229282
# 9            0.225958
# 38           0.225343
# 14           0.220531
# 41           0.219831
# 20           0.216396
# 13           0.216263
# 36           0.216024
# 7            0.207871
# 6            0.207234
# 27           0.206074
# 37           0.204560
# 0            0.198153
# 39           0.197774
# 17           0.189011
# 1            0.169788
# 16           0.169521
# 33           0.157135
# 12           0.156440
# 31           0.129687

# %%
cat_car_similarity = cosine_similarity([cat_embedding.data[0].embedding], [car_embedding.data[0].embedding])[0][0]
cat_car_similarity
# Out:
# 0.5156173418297144

# %%
cat_dog_similarity = cosine_similarity([cat_embedding.data[0].embedding], [dog_embedding.data[0].embedding])[0][0]
cat_dog_similarity
# Out:
# 0.602501803670552

# %% [markdown]
# ## Search for Complex Search Term

# %%
# Read the data file
data = pd.read_csv('assets/words_with_embeddings.csv')
data['embedding'] = data['embedding'].apply(eval).apply(np.array)
data
milk_vector = data['embedding'].iloc[21]  # Get the embedding of the word at index 21
tea_vector = data['embedding'].iloc[22]  # Get the embedding of the word at index 22

complex_vector = milk_vector + tea_vector

# %%
data['cosine_similarity'] = data['embedding'].apply(lambda x: cosine_similarity([complex_vector], [x])[0][0])
data = data.sort_values(by='cosine_similarity', ascending=False)
data
# Out:
#           text                                          embedding  \
# 22         tea  [-0.01637290231883526, -0.030905066058039665, ...
# 21        milk  [0.03963107243180275, -0.00417668791487813, -0...
# 5       coffee  [-0.010105200111865997, 0.0037400261498987675,...
# 8         soda  [0.018451469019055367, -0.025056716054677963, ...
# 10  cappuccino  [-0.024895260110497475, -0.030884910374879837,...
# 40       water  [0.0030196786392480135, 0.017477955669164658, ...
# 32       pasta  [-0.05013786256313324, -0.04082654416561127, 0...
# 29       salad  [-0.0006578968022949994, -0.03706714138388634,...
# 35       white  [0.0032686665654182434, -0.028257660567760468,...
# 3       purple  [0.02472393959760666, -0.034728385508060455, -...
# 24    sandwich  [-0.005682190880179405, -0.04893353208899498, ...
# 26        fish  [-0.002734047593548894, -0.021766602993011475,...
# 38       green  [0.006235065869987011, -0.0011298545869067311,...
# 30       pizza  [-0.01020066812634468, -0.028279945254325867, ...
# 15      burger  [-0.03550729528069496, -0.01598917506635189, 0...
# 23        blue  [-0.0011808431008830667, -0.016510002315044403...
# 41      orange  [-0.025900742039084435, -0.005591441877186298,...
# 36         cat  [0.025529420003294945, -0.023411665111780167, ...
# 34       brown  [-0.030695391818881035, -0.00717085599899292, ...
# 28        bear  [0.04613043740391731, -0.01706441305577755, -0...
# 9       yellow  [-0.014238273724913597, -0.018038872629404068,...
# 14     hamster  [0.03871235251426697, -0.027450142428278923, 0...
# 2        black  [0.01116090640425682, -0.012063156813383102, -...
# 11        deer  [0.060825735330581665, -0.03296774625778198, 0...
# 20         red  [-0.022114494815468788, -0.010901302099227905,...
# 7         hare  [0.01832250878214836, -0.0220760777592659, 0.0...
# 39        gray  [0.004804749041795731, -0.020221514627337456, ...
# 6       rabbit  [0.006220409180969, -0.015751302242279053, 0.0...
# 33      turtle  [0.028160911053419113, -0.016313010826706886, ...
# 27         dog  [0.05113774910569191, -0.01870863139629364, -0...
# 18    squirrel  [0.03322089836001396, -0.04075725004076958, -0...
# 25      coyote  [0.04016764461994171, -0.031213432550430298, -...
# 12        bird  [0.05648331344127655, -0.0011298867175355554, ...
# 19      lizard  [0.012100729160010815, -0.012437433004379272, ...
# 0          fox  [-0.03355345129966736, 0.001505932305008173, -...
# 17        wolf  [-0.0030049828346818686, -0.026660829782485962...
# 4       badger  [0.021644549444317818, -0.022302215918898582, ...
# 13     raccoon  [0.05898168683052063, -0.0009809075854718685, ...
# 16      ferret  [0.006305847316980362, -0.041793812066316605, ...
# 37  guinea pig  [0.007524285465478897, -0.026610590517520905, ...
# 31       snake  [0.051066912710666656, -0.020128140226006508, ...
# 1      opossum  [0.03196421265602112, 0.03251579403877258, -0....
#
#     cosine_similarity
# 22           0.814000
# 21           0.814000
# 5            0.584376
# 8            0.455589
# 10           0.448989
# 40           0.441671
# 32           0.431922
# 29           0.415339
# 35           0.406285
# 3            0.394688
# 24           0.391731
# 26           0.377896
# 38           0.375566
# 30           0.373685
# 15           0.372072
# 23           0.362266
# 41           0.354166
# 36           0.352579
# 34           0.351992
# 28           0.343039
# 9            0.341836
# 14           0.334279
# 2            0.329259
# 11           0.327420
# 20           0.320033
# 7            0.317517
# 39           0.304461
# 6            0.302550
# 33           0.302412
# 27           0.300210
# 18           0.292546
# 25           0.288825
# 12           0.282265
# 19           0.279724
# 0            0.278564
# 17           0.276550
# 4            0.268326
# 13           0.264098
# 16           0.251360
# 37           0.248005
# 31           0.224222
# 1            0.206781

# %% [markdown]
# # Note
# as a breaking change OpenAI deleted utils.embeddings_utils library from the OpenAi package and didn't updated the Open AI cookbook yet so if you faced any tutorial or course referencing a method from this library you can manually copy the method code from this file https://github.com/openai/openai-cookbook/blob/main/examples/utils/embeddings_utils.py till OpenAI fix this issue and support an alternative
