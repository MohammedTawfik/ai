# %% [markdown]
# # Books Recommendation System

# %% [markdown]
# ## Import the needed libraries

# %%
import os
import pandas as pd
import numpy as np
import tiktoken
from openai import OpenAI
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Read the Open API Key from .env file

# %%
import os
from dotenv import load_dotenv, find_dotenv
# find_dotenv() find .env automatically by walking up directories until it's found 
# load_dotenv() load the environment variables from the .env file
# override=True allows the .env file to override the system environment variables
load_dotenv(find_dotenv(), override=True)

apiKey = os.environ.get('OPENAI_API_KEY')

# %% [markdown]
# ## Create OpenAI Client

# %%
client = OpenAI(api_key=apiKey)

# %% [markdown]
# ## Read the dat file from disk

# %%
books_data = pd.read_csv('books_dataset.csv')
books_data
# Out:
#              isbn13                      title  \
# 0     9780002005883                     Gilead
# 1     9780002261982               Spider's Web
# 2     9780006163831               The One Tree
# 3     9780006178736             Rage of angels
# 4     9780006280897             The Four Loves
# ...             ...                        ...
# 6805  9788185300535                  I Am that
# 6806  9788185944609       Secrets Of The Heart
# 6807  9788445074879             Fahrenheit 451
# 6808  9789027712059   The Berlin Phenomenology
# 6809  9789042003408  'I'm Telling You Stories'
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                             Stephen R. Donaldson
# 3                                   Sidney Sheldon
# 4                              Clive Staples Lewis
# ...                                            ...
# 6805  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6806                                 Khalil Gibran
# 6807                                  Ray Bradbury
# 6808                 Georg Wilhelm Friedrich Hegel
# 6809                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                  American fiction
# 3                           Fiction
# 4                    Christian life
# ...                             ...
# 6805                     Philosophy
# 6806                      Mysticism
# 6807                   Book burning
# 6808                        History
# 6809             Literary Criticism
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# ...                                                 ...             ...
# 6805  This collection of the timeless teachings of o...          1999.0
# 6806                                                NaN          1993.0
# 6807                                                NaN          2004.0
# 6808  Since the three volume edition ofHegel's Philo...          1981.0
# 6809  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating
# 0               3.85
# 1               3.83
# 2               3.97
# 3               3.93
# 4               4.15
# ...              ...
# 6805            4.51
# 6806            4.08
# 6807            3.98
# 6808            0.00
# 6809            3.70
#
# [6810 rows x 7 columns]

# %% [markdown]
# ## Drop Records with Empty Data
# - As shown in when we display the loaded data records 6807 and 6808 have empty description (converted to NaN by Pandas)
# - there are different ways to handle NaN values
#   - Drop the records to not affect the training process
#   - Fill them with a constant value
#   - Interpolate NaN Values: the process of estimating missing values based on the values of neighboring data points.
#
# For this app we will drop them using dropna method from pandas (it will remove the whole record if at lease one column has NaN value)

# %%
books_data = books_data.dropna()
books_data

#check the different count of the data record after removing the null values
# Out:
#              isbn13                                              title  \
# 0     9780002005883                                             Gilead
# 1     9780002261982                                       Spider's Web
# 2     9780006163831                                       The One Tree
# 3     9780006178736                                     Rage of angels
# 4     9780006280897                                     The Four Loves
# ...             ...                                                ...
# 6803  9788173031014                                Journey to the East
# 6804  9788179921623  The Monk Who Sold His Ferrari: A Fable About F...
# 6805  9788185300535                                          I Am that
# 6808  9789027712059                           The Berlin Phenomenology
# 6809  9789042003408                          'I'm Telling You Stories'
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                             Stephen R. Donaldson
# 3                                   Sidney Sheldon
# 4                              Clive Staples Lewis
# ...                                            ...
# 6803                                 Hermann Hesse
# 6804                                  Robin Sharma
# 6805  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 6808                 Georg Wilhelm Friedrich Hegel
# 6809                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                  American fiction
# 3                           Fiction
# 4                    Christian life
# ...                             ...
# 6803              Adventure stories
# 6804               Health & Fitness
# 6805                     Philosophy
# 6808                        History
# 6809             Literary Criticism
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4     Lewis' work on the nature of love divides love...          2002.0
# ...                                                 ...             ...
# 6803  This book tells the tale of a man who goes on ...          2002.0
# 6804  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 6805  This collection of the timeless teachings of o...          1999.0
# 6808  Since the three volume edition ofHegel's Philo...          1981.0
# 6809  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating
# 0               3.85
# 1               3.83
# 2               3.97
# 3               3.93
# 4               4.15
# ...              ...
# 6803            3.70
# 6804            3.82
# 6805            4.51
# 6808            0.00
# 6809            3.70
#
# [6411 rows x 7 columns]

# %%
# Select only the first 2000 book records for the analysis to reduce the computation time and cost
books_data = books_data.sort_values(by='average_rating', ascending=True).head(2000)
books_data
# Out:
#              isbn13                               title  \
# 5213  9780812927634  Random House Crossword Megaomnibus
# 1635  9780313309335               The Fantastic Vampire
# 6739  9781932206104                     How to Meditate
# 4479  9780744005615                              Juiced
# 1750  9780340774779          The Road to War, 1933-1939
# ...             ...                                 ...
# 1587  9780312890216                     The Starry Rift
# 1211  9780192837684         The Eclogues ; The Georgics
# 1217  9780192839572              La chartreuse de Parme
# 5770  9781400079179                   The Da Vinci Code
# 1732  9780330487191               A House for Mr Biswas
#
#                             authors              categories  \
# 5213     United Feature Syndication                   Games
# 1635              James Craig Holte      Literary Criticism
# 6739                 Frederick Lenz              Meditation
# 4479                     Doug Walsh                   Games
# 1750                    Andrew Hunt                 Germany
# ...                             ...                     ...
# 1587                  James Tiptree                 Fiction
# 1211                         Virgil             Agriculture
# 1217                    Jm Stendhal                 Fiction
# 5770                      Dan Brown                 Fiction
# 1732  Vidiadhar Surajprasad Naipaul  Autonomy (Psychology).
#
#                                             description  published_year  \
# 5213  his new series contains crosswords slightly le...          1997.0
# 1635  Wherever vampires existed in the imaginations ...          2002.0
# 6739  How to Meditate is a transcript all of Rama's,...          2004.0
# 4479  BradyGames' Juiced Official Strategy Guide inc...          2005.0
# 1750  This text uses a source-based approach to stud...          2000.0
# ...                                                 ...             ...
# 1587  This novel set in the far-future and filled wi...          1994.0
# 1211  The Eclogues, ten short pastoral poems, were c...          1999.0
# 1217  Follows the adventures of young Fabrizio del D...          1999.0
# 5770  Harvard symbologist Robert Langdon and French ...          2006.0
# 1732  A House for Mr Biswas is V.S. Naipaul's unforg...          1961.0
#
#       average_rating
# 5213            0.00
# 1635            0.00
# 6739            0.00
# 4479            0.00
# 1750            0.00
# ...              ...
# 1587            3.82
# 1211            3.82
# 1217            3.82
# 5770            3.82
# 1732            3.82
#
# [2000 rows x 7 columns]

# %% [markdown]
# ## Calculate the Embedding Cost

# %%
def get_embedding(text):
    text = text.replace('\n', ' ')
    response = client.embeddings.create(model='text-embedding-3-small', input=text)
    return response.data[0].embedding

# %%
def calculate_embedding_cost(books_data):
    # Calculate the number of tokens in the books dataset
    data_as_list = list(books_data['description'])
    enc = tiktoken.encoding_for_model(model_name="text-embedding-3-small")
    total_tokens = sum([len(enc.encode(desc)) for desc in data_as_list])
    print(f"Total tokens: {total_tokens}")
    cost = total_tokens * (0.00002/1000)
    print(f"Cost: ${cost:.20f}")

# %%
calculate_embedding_cost(books_data)
# Out:
# Total tokens: 178031
# Cost: $0.00356062000000000002

# %% [markdown]
# ## Calculate the Embeddings and Store them Locally

# %%
def get_embeddings_and_save_to_csv():
    books_data['embedding'] = books_data['description'].apply(lambda x: get_embedding(x))
    books_data.to_csv('books_dataset_with_embeddings.csv', index=False)

# %%
get_embeddings_and_save_to_csv()

# %% [markdown]
# ## Load the Embeddings

# %%
books_with_embeddings = pd.read_csv('books_dataset_with_embeddings.csv')
books_with_embeddings["embedding"] = books_with_embeddings["embedding"].apply(eval).apply(np.array)
books_with_embeddings
# Out:
#              isbn13                               title  \
# 0     9780812927634  Random House Crossword Megaomnibus
# 1     9780313309335               The Fantastic Vampire
# 2     9781932206104                     How to Meditate
# 3     9780744005615                              Juiced
# 4     9780340774779          The Road to War, 1933-1939
# ...             ...                                 ...
# 1995  9780312890216                     The Starry Rift
# 1996  9780192837684         The Eclogues ; The Georgics
# 1997  9780192839572              La chartreuse de Parme
# 1998  9781400079179                   The Da Vinci Code
# 1999  9780330487191               A House for Mr Biswas
#
#                             authors              categories  \
# 0        United Feature Syndication                   Games
# 1                 James Craig Holte      Literary Criticism
# 2                    Frederick Lenz              Meditation
# 3                        Doug Walsh                   Games
# 4                       Andrew Hunt                 Germany
# ...                             ...                     ...
# 1995                  James Tiptree                 Fiction
# 1996                         Virgil             Agriculture
# 1997                    Jm Stendhal                 Fiction
# 1998                      Dan Brown                 Fiction
# 1999  Vidiadhar Surajprasad Naipaul  Autonomy (Psychology).
#
#                                             description  published_year  \
# 0     his new series contains crosswords slightly le...          1997.0
# 1     Wherever vampires existed in the imaginations ...          2002.0
# 2     How to Meditate is a transcript all of Rama's,...          2004.0
# 3     BradyGames' Juiced Official Strategy Guide inc...          2005.0
# 4     This text uses a source-based approach to stud...          2000.0
# ...                                                 ...             ...
# 1995  This novel set in the far-future and filled wi...          1994.0
# 1996  The Eclogues, ten short pastoral poems, were c...          1999.0
# 1997  Follows the adventures of young Fabrizio del D...          1999.0
# 1998  Harvard symbologist Robert Langdon and French ...          2006.0
# 1999  A House for Mr Biswas is V.S. Naipaul's unforg...          1961.0
#
#       average_rating                                          embedding
# 0               0.00  [-0.018283704295754433, -0.015245502814650536,...
# 1               0.00  [-0.030094962567090988, 0.035030536353588104, ...
# 2               0.00  [-0.0060596163384616375, 0.025496121495962143,...
# 3               0.00  [0.036799781024456024, 0.04352662339806557, -0...
# 4               0.00  [-0.015587965957820415, 0.03728048503398895, 0...
# ...              ...                                                ...
# 1995            3.82  [0.0023731449618935585, 0.042326465249061584, ...
# 1996            3.82  [0.021905047819018364, 0.014567454345524311, 0...
# 1997            3.82  [-0.021207181736826897, -0.004873700439929962,...
# 1998            3.82  [-0.008561644703149796, 0.029169591143727303, ...
# 1999            3.82  [0.03393647447228432, 0.04061787575483322, 0.0...
#
# [2000 rows x 8 columns]

# %% [markdown]
# ## Create Recommendations Function

# %%
# %pip install matplotlib -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install plotly -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import textwrap as tr
from typing import List, Optional

import matplotlib.pyplot as plt
import plotly.express as px
from scipy import spatial
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import average_precision_score, precision_recall_curve
# Utility Methods
def distances_from_embeddings(
    query_embedding: List[float],
    embeddings: List[List[float]],
    distance_metric="cosine",
) -> List[List]:
    """Return the distances between a query embedding and a list of embeddings."""
    distance_metrics = {
        "cosine": spatial.distance.cosine,
        "L1": spatial.distance.cityblock,
        "L2": spatial.distance.euclidean,
        "Linf": spatial.distance.chebyshev,
    }
    distances = [
        distance_metrics[distance_metric](query_embedding, embedding)
        for embedding in embeddings
    ]
    return distances

def indices_of_nearest_neighbors_from_distances(distances) -> np.ndarray:
    """Return a list of indices of nearest neighbors from a list of distances."""
    return np.argsort(distances)

# %%
def get_recommendations_from_title(df_embeddings, title, n=5):
    if title not in df_embeddings['title'].values:
        print(f"Title '{title}' not found in the dataset")
        return False
    
    #Get text embedding for the title from the embeddings file
    title_embedding = df_embeddings[df_embeddings['title'] == title]['embedding']
    title_embedding = title_embedding.squeeze()
    all_embeddings = list(df_embeddings['embedding'])
    
    distances = distances_from_embeddings(title_embedding, all_embeddings)
    indices_of_nearest_neighbors = indices_of_nearest_neighbors_from_distances(distances)
    #print(indices_of_nearest_neighbors)
    
    recommendations = list()
    for index in indices_of_nearest_neighbors[1:n+1]:
        book = dict()
        book['title'] = df_embeddings.iloc[index]['title']
        book['description'] = df_embeddings.iloc[index]['description']
        book['distance'] = distances[index]
        recommendations.append(book)
    return recommendations

# %%
get_recommendations_from_title(books_with_embeddings, "Juiced", n=5)
# Out:
# [{'title': 'Medal of Honor Rising Sun',
#   'description': 'Playmakers Win Championships -Online strategies for the PlayStation(R)2 computer entertainment system -Expert offensive and defensive strategies -Tips for success in every mode, including the new Owner Mode -How to unlock all hidden rewards -Profiles, statistics, and key plays for every team',
#   'distance': 0.4523883173313282},
#  {'title': 'Castlevania',
#   'description': "BradyGames' Castlevania: Curse of Darkness Official Strategy Guide includes the following: A complete walkthrough of the entire game. Detailed maps of every area. In-depth listing of unlockables, items and weapons. Expert strategies to defeat every boss. Extensive bestiary. Game secrets revealed! Platform: PlayStation 2 Genre: Action/AdventureThis product is available for sale in North America only.",
#   'distance': 0.45504904353297027},
#  {'title': 'Hardball',
#   'description': 'Hardball takes leaders deep inside the world of hardball competition - a world where the players are zealously committed to winning and relentlessly driven to strengthen their competitive positions, creating a virtuous cycle that puts them far out of competitors\' reach. Based on twenty-five years of experience advising and observing a range of companies, Stalk and Lachenauer reveal how hardball competitors achieve decisive victories - without bending the law and without compromising their obligations to customers and stakeholders. These companies often play rough, and they don\'t apologize for it. Yet they are also extraordinarily adept at the "soft" side of management - rallying talent and building culture through a laserlike focus on the few issues most critical to success. Using detailed and engaging stories from many industries, Hardball outlines seven classic hardball strategies: unleash massive and overwhelming force, exploit anomalies, threaten competitors\' profit sanctuaries, take it and make it your own, entice competitors\' into retreat, break industry compromises, and hardball M&A. The authors reveal who uses hardball strategies, under what circumstances each strategy is most effective, and how to orchestrate the attack.',
#   'distance': 0.7285059829134511},
#  {'title': 'Full Speed',
#   'description': "Treat yourself to FULL SPEED by Janet Evanovich and Charlotte Hughes. Praise for the FULL series: 'A fine romance with plenty of kisses' Mirror; 'A wild mix of intrigue, sex and pyrotechnics' The Times Their enemies haven't got a prayer... Journalist Jamie Swift and millionaire Max Holt drive each other crazy when they work together - but they just can't stop. Especially when they both have their reasons for wanting to investigate a charismatic preacher with suspected ties to the Mob and a long history with his female church members. The trouble is, someone has got wind of Jamie and Max's snooping around, and is pretty eager to introduce them to their Maker - a lot sooner than either Jamie or Max had planned...",
#   'distance': 0.7298221706069294},
#  {'title': 'Be More Chill',
#   'description': 'Jeremy Heere is your average high school dork. Day after day, he stares at beautiful Christine, the girl he can never have, and dryly notes the small humiliations that come his way. Until the day he learns about the "squip." A pill-sized supercomputer that you swallow, the squip is guaranteed to bring you whatever you most desire in life. By instructing him on everything from what to wear, to how to talk and walk, the squip transforms Jeremy from Supergeek to superchic.',
#   'distance': 0.7360691439144869}]

# %% [markdown]
# ## Testing

# %%
title = input("Enter the title of the book: ")

recommendations = get_recommendations_from_title(books_with_embeddings, title, n=5)

if recommendations:
    for i, recommendation in enumerate(recommendations):
        print(f"Recommendation {i+1}:")
        print(f"Title: {recommendation['title']}")
        print(f"Description: {recommendation['description']}")
        print(f"Distance: {recommendation['distance']}")
        print("\n")
else:
    print("Title not found in the dataset. Please try again.")
# Out:
# Recommendation 1:
# Title: The Rule of Four
# Description: Trying to decipher an ancient text that weaves a mathematical labyrinth within a love story, two researchers obtain a diary that may contain the key to the code, but when a fellow researcher is killed, they realize that the book contains a dangerous secret.
# Distance: 0.4417196933140113
#
#
# Recommendation 2:
# Title: The Guide to Dan Brown's The Solomon Key
# Description: The massive success of Dan Brown's The Da Vinci Code has readers eagerly awaiting his next novel, The Solomon Key. Using clues left by Brown in interviews, on his website, and on the cover of The Da Vinci Code, Greg Taylor takes you on an unprecedented tour of the new book before it is even released. The Guide to Dan Brown's The Solomon Key explores the topics likely to be included in Brown's next novel - including the hidden history of Washington, D.C., Freemasonry, and even the Ku Klux Klan - to give you a better understanding of the concepts behind the book. With no spoilers, this is the essential primer for The Solomon Key. Book jacket.
# Distance: 0.5268875731512395
#
#
# Recommendation 3:
# Title: The Lost Painting
# Description: Recounts the search for a long-lost masterpiece by Italian Baroque master Michelangelo Caravaggio, following a young graduate student across hundreds of years and four countries to uncover the mystery of "The Taking of Christ."
# Distance: 0.5344941358472788
#
#
# Recommendation 4:
# Title: The Various Haunts of Men
# Description: In the wake of a series of disappearances on a foggy and tranquil area of a cathedral town known locally as "the Hill," dedicated young policewoman Freya Graffham and enigmatic detective Chief Inspector Simon Serrailler follow a series of clues in order to decode the mind of a twisted serial killer.
# Distance: 0.5366108217952659
#
#
# Recommendation 5:
# Title: The Raphael Affair
# Description: When a long-lost Raphael resurfaces, the painting triggers a chain of events that range from vandalism to murder, prompting an investigation by English art scholar Jonathan Argyll, who ends up on the run for his life. Reprint.
# Distance: 0.5452305070729726

# %%
print(books_with_embeddings.iloc[3]['description'])
# Out:
# BradyGames' Juiced Official Strategy Guide includes the following: Track Maps: Each map is broken down to give you the best chance of winning. Full Car List: Get all the stats on all the hottest rides! Crew Management Tips: Get the best crew and learn what it takes to win! Rival Crew Challenges: Discover the ins and outs of every challenge and get the best strategy to crush rival crews! And More: Racing schedules, part listings, pro tips, crewmate data, and showoff tricks! Platform: PlayStation 2, Xbox, & PC Genre: Sports/Racing This title is available for sale worldwide.

# %% [markdown]
# ## Visualize The Embeddings
# - As the embeddings are just some numbers we will not be able to understand them but using some tools to visualize and show the relations between the data
# - (Atlas)[https://atlas.nomic.ai/discover] is one of the tools that can do this job
# - It avail APIs so you can visualize your own data

# %%
# %pip install nomic -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from nomic import atlas

# %%
books = pd.read_csv('books_dataset_with_embeddings.csv')
books['embedding'] = books['embedding'].apply(eval).apply(np.array)

# %%
books_dict = books[['title','authors','categories']].to_dict('records')
books_dict
# Out:
# [{'title': 'Random House Crossword Megaomnibus',
#   'authors': 'United Feature Syndication',
#   'categories': 'Games'},
#  {'title': 'The Fantastic Vampire',
#   'authors': 'James Craig Holte',
#   'categories': 'Literary Criticism'},
#  {'title': 'How to Meditate',
#   'authors': 'Frederick Lenz',
#   'categories': 'Meditation'},
#  {'title': 'Juiced', 'authors': 'Doug Walsh', 'categories': 'Games'},
#  {'title': 'The Road to War, 1933-1939',
#   'authors': 'Andrew Hunt',
#   'categories': 'Germany'},
#  {'title': 'American writers',
#   'authors': 'Gale Group',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Berlin Phenomenology',
#   'authors': 'Georg Wilhelm Friedrich Hegel',
#   'categories': 'History'},
#  {'title': 'Open City 6',
#   'authors': 'Thomas Beller;James Purdy;Strawberry Saroyan;Debra Garrison;Michael Cunningham',
#   'categories': 'Fiction'},
#  {'title': 'World Studies: Eastern Hemisphere',
#   'authors': 'Heidi Hayes Jacobs;Pearson Prentice Hall;Kate Kinsella;Michal L. LeVasseur',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'V.S. Naipaul, Second Edition',
#   'authors': 'Bruce King',
#   'categories': 'Literary Criticism'},
#  {'title': 'Crackup',
#   'authors': 'Len Morgan',
#   'categories': 'Aircraft accidents'},
#  {'title': 'Erotica', 'authors': 'Kelly Carr', 'categories': 'Fiction'},
#  {'title': 'Field Guide to Home Buying in America',
#   'authors': 'Stephen M. Pollan;Mark Levine',
#   'categories': 'Business & Economics'},
#  {'title': 'Ten Days in the Hills',
#   'authors': 'Jane Smiley',
#   'categories': 'Fiction'},
#  {'title': 'The Trouble with the Pears',
#   'authors': 'Gia Bathory Al Babel',
#   'categories': 'Fiction'},
#  {'title': 'The 13th directorate',
#   'authors': 'Barry Chubin',
#   'categories': 'Fiction'},
#  {'title': 'The Governess',
#   'authors': 'Sarah Fielding',
#   'categories': 'Fiction'},
#  {'title': 'Healthy Cooking for IBS',
#   'authors': 'Sophie Braimbridge;Erica Jankovich',
#   'categories': 'Cooking'},
#  {'title': 'Crash Course in Web Design for Libraries',
#   'authors': 'Charles P. Rubenstein',
#   'categories': 'Computers'},
#  {'title': 'Mind Over Money',
#   'authors': 'John W. Schott;Jean S. Arbeiter',
#   'categories': 'Business & Economics'},
#  {'title': 'The birds',
#   'authors': "Aristophanes;Sean O'Brien",
#   'categories': 'Drama'},
#  {'title': 'Juneau and Sauk Counties',
#   'authors': 'Jacqueline Ann;Sheila Zenk',
#   'categories': 'History'},
#  {'title': 'Numerical Recipes Example Book (C++)',
#   'authors': 'William T. Vetterling',
#   'categories': 'Computers'},
#  {'title': "Bright Star's Promise",
#   'authors': 'Karen A. Bale',
#   'categories': 'Fiction'},
#  {'title': 'Yellow Dog', 'authors': 'Martin Amis', 'categories': 'Fiction'},
#  {'title': 'Four Blondes',
#   'authors': 'Candace Bushnell',
#   'categories': 'Fiction'},
#  {'title': 'Teleportation: From Star Trek to Tesla',
#   'authors': 'Commander X;Tim Swartz',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'The Parrot Head Companion',
#   'authors': 'Thomas Ryan',
#   'categories': 'Music'},
#  {'title': 'Desire and Duty',
#   'authors': 'Teddy F. Bader;Marilyn Bader',
#   'categories': 'Fiction'},
#  {'title': 'Challengers of the Unknown',
#   'authors': 'Howard Chaykin;Michelle Madsen',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Indecision',
#   'authors': 'Benjamin Kunkel',
#   'categories': 'Fiction'},
#  {'title': 'Queen of the Underworld',
#   'authors': 'Gail Godwin',
#   'categories': 'Fiction'},
#  {'title': 'Checkpoint',
#   'authors': 'Nicholson Baker',
#   'categories': 'Fiction'},
#  {'title': 'Crazy',
#   'authors': 'Benjamin Lebert',
#   'categories': 'Handicapped youth'},
#  {'title': 'Lost: Secret Identity - Novelization #2',
#   'authors': 'Cathy Hapka',
#   'categories': 'Fiction'},
#  {'title': 'Mistaken Identity',
#   'authors': 'Nayantara Sahgal',
#   'categories': 'Indic fiction (English)'},
#  {'title': 'Orientalism',
#   'authors': 'John MacKenzie;John MacDonald MacKenzie',
#   'categories': 'Art'},
#  {'title': 'American Government',
#   'authors': "Karen O'Connor;Larry Sabato",
#   'categories': 'Political Science'},
#  {'title': "The Easter Rabbit's Parade",
#   'authors': 'Lois Lenski',
#   'categories': 'Juvenile Fiction'},
#  {'title': "The Guide to Dan Brown's The Solomon Key",
#   'authors': 'Greg Taylor',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'Selections from the Oakland Tribune Archives',
#   'authors': 'Annalee Allen',
#   'categories': 'History'},
#  {'title': 'Sukhoi Su-27 Flanker',
#   'authors': 'Yefim Gordon;Peter Davison',
#   'categories': 'History'},
#  {'title': "C++ Programmer's Notebook",
#   'authors': 'James Edward Keogh;John Shapley Gray',
#   'categories': 'Computers'},
#  {'title': "CliffsNotes on Woolf's Mrs. Dalloway",
#   'authors': 'Gary Carey',
#   'categories': 'Literary Criticism'},
#  {'title': 'Cypress Gardens',
#   'authors': 'Mary M. Flekke;Sarah E. MacDonald;Randall M. MacDonald',
#   'categories': 'History'},
#  {'title': "The Aristotle's Ethics",
#   'authors': 'Aristotle',
#   'categories': 'Study Aids'},
#  {'title': 'Erotica', 'authors': 'Kelly Carr', 'categories': 'Fiction'},
#  {'title': 'Southwest France',
#   'authors': 'John King;Julia Wilkinson',
#   'categories': 'Travel'},
#  {'title': 'Flowers for Algernon',
#   'authors': 'Patrice Cassedy',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': "Nightingale's Song",
#   'authors': 'Kate Pennington',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'New Media Language',
#   'authors': 'Jean Aitchison;Diana M. Lewis',
#   'categories': 'Language Arts & Disciplines'},
#  {'title': 'The Toy Maker',
#   'authors': 'Anthony McReavy',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'White Widow', 'authors': 'Jim Lehrer', 'categories': 'Fiction'},
#  {'title': 'In the Kitchen with Rosie',
#   'authors': 'Rosie Daley',
#   'categories': 'Cooking'},
#  {'title': 'The Truth of the Matter',
#   'authors': 'Robb Forman Dew',
#   'categories': 'Fiction'},
#  {'title': 'The Black Veil',
#   'authors': 'Rick Moody',
#   'categories': 'Family & Relationships'},
#  {'title': 'Run',
#   'authors': 'William Sleator',
#   'categories': 'Detective and mystery stories'},
#  {'title': 'Garden State', 'authors': 'Rick Moody', 'categories': 'Teenagers'},
#  {'title': 'The Big Bing',
#   'authors': 'Stanley Bing',
#   'categories': 'Business & Economics'},
#  {'title': 'The Jane Austen Book Club',
#   'authors': 'Karen Joy Fowler',
#   'categories': 'Fiction'},
#  {'title': 'The 3-Hour Diet (TM) On the Go (Collins Gem)',
#   'authors': 'Jorge Cruise',
#   'categories': 'Health & Fitness'},
#  {'title': 'Sizzle', 'authors': 'Jennifer Crusie', 'categories': 'Fiction'},
#  {'title': 'Billy Budd, Sailor',
#   'authors': 'Herman Melville',
#   'categories': 'Fiction'},
#  {'title': 'Billy Budd, Sailor and Other Uncompleted Writings',
#   'authors': 'Herman Melville',
#   'categories': 'Fiction'},
#  {'title': 'Bored of the Rings',
#   'authors': 'Henry Beard;Harvard Lampoon;Douglas C. Kenney',
#   'categories': 'Fiction'},
#  {'title': 'The Twenty-seventh City',
#   'authors': 'Jonathan Franzen',
#   'categories': 'Detective and mystery stories'},
#  {'title': 'The Mermaid Chair',
#   'authors': 'Sue Monk Kidd',
#   'categories': 'Fiction'},
#  {'title': 'The Franklin Affair',
#   'authors': 'Jim Lehrer',
#   'categories': 'Fiction'},
#  {'title': 'The Secret Society of Demolition Writers',
#   'authors': 'Aimee Bender;Marc Parent',
#   'categories': 'Fiction'},
#  {'title': 'The Twenty-Seventh City',
#   'authors': 'Jonathan Franzen',
#   'categories': 'Fiction'},
#  {'title': 'The Castle in the Forest',
#   'authors': 'Norman Mailer',
#   'categories': 'Fiction'},
#  {'title': 'Hawkes Harbor',
#   'authors': 'S. E. Hinton',
#   'categories': 'Fiction'},
#  {'title': 'The Career Programmer',
#   'authors': 'Christopher Duncan',
#   'categories': 'Computers'},
#  {'title': 'Baby Einstein: Sweet Dreams, Mimi',
#   'authors': 'Julie Aigner-Clark',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Cervantes in Algiers',
#   'authors': 'María Antonia Garcés',
#   'categories': 'Health & Fitness'},
#  {'title': 'The Stones of Summer',
#   'authors': 'Dow Mossman',
#   'categories': 'Fiction'},
#  {'title': 'The Autograph Man',
#   'authors': 'Zadie Smith',
#   'categories': 'Fiction'},
#  {'title': 'Boogaloo on 2nd Avenue',
#   'authors': 'Mark Kurlansky',
#   'categories': 'Fiction'},
#  {'title': 'Think Like a Guy',
#   'authors': 'Giuliana Depandi',
#   'categories': 'Family & Relationships'},
#  {'title': 'Bad Dreams', 'authors': 'Kim Newman', 'categories': 'Fiction'},
#  {'title': 'The Autograph Man',
#   'authors': 'Zadie Smith',
#   'categories': 'Fiction'},
#  {'title': 'Monkey Business',
#   'authors': 'Marvin N. Olasky;John Perry',
#   'categories': 'Religion'},
#  {'title': '"A" is for Abductive',
#   'authors': 'Leonard I. Sweet;Brian D. McLaren;Jerry Haselmayer',
#   'categories': 'Religion'},
#  {'title': 'Terrorist', 'authors': 'John Updike', 'categories': 'Fiction'},
#  {'title': 'Lies, Inc', 'authors': 'Philip K. Dick', 'categories': 'Fiction'},
#  {'title': 'Pledged',
#   'authors': 'Alexandra Robbins',
#   'categories': 'Education'},
#  {'title': 'The Castle of Otranto',
#   'authors': 'Horace Walpole',
#   'categories': 'Fiction'},
#  {'title': 'Superman',
#   'authors': 'Kurt Busiek;Fabian Nicieza;Pete Woods;Len Wein;Gerry Conway;José Luis García-López',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Tinsel', 'authors': 'William Goldman', 'categories': 'Fiction'},
#  {'title': 'First Love',
#   'authors': 'Joyce Carol Oates',
#   'categories': 'Fiction'},
#  {'title': 'The Little Baby Snoogle-Fleejer',
#   'authors': 'Jimmy Carter',
#   'categories': 'Friendship'},
#  {'title': 'Serious Girls',
#   'authors': 'Maxine Swann',
#   'categories': 'Fiction'},
#  {'title': 'Wind Child', 'authors': 'Nancy Harding', 'categories': 'Fiction'},
#  {'title': 'This Christmas',
#   'authors': 'Jane Green;Jennifer Coburn;Liz Ireland',
#   'categories': 'Fiction'},
#  {'title': 'BLOOD SUCKER Volume 1: Legend of "Zipangu"',
#   'authors': 'Saki Okuse;Aki Shimizu',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Persuasive Writing',
#   'authors': 'Tara McCarthy',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Songs of the Humpback Whale',
#   'authors': 'Jodi Picoult',
#   'categories': 'Fiction'},
#  {'title': 'Exercitia Spiritualia',
#   'authors': 'Saint Gertrude (the Great)',
#   'categories': 'Religion'},
#  {'title': 'Scary Edwin Page',
#   'authors': 'Alec Sillifant;Daniel Postgate',
#   'categories': "Children's stories"},
#  {'title': 'The Mini Zen Gardening Kit',
#   'authors': 'Abd Al-Hayy Moore',
#   'categories': 'Gardening'},
#  {'title': 'The Zen Gardening Kit',
#   'authors': 'Running Press',
#   'categories': 'Gardening'},
#  {'title': 'The Serial Killers Club',
#   'authors': 'Jeff Povey',
#   'categories': 'Fiction'},
#  {'title': 'Cry, the Peacock',
#   'authors': 'Anita Desai',
#   'categories': 'Fiction'},
#  {'title': "Don't Wait for Your Ship to Come In",
#   'authors': 'John Mason',
#   'categories': 'Religion'},
#  {'title': 'The Rule of Four',
#   'authors': 'Ian Caldwell;Dustin Thomason',
#   'categories': 'Fiction'},
#  {'title': 'Cosmopolis', 'authors': 'Don DeLillo', 'categories': 'Fiction'},
#  {'title': 'Sociology in Our Times',
#   'authors': 'Diana Kendall',
#   'categories': 'Science'},
#  {'title': 'Sophie Pitt-Turnbull Discovers America',
#   'authors': 'Dyan Sheldon',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Radical Right and the Murder of John F. Kennedy',
#   'authors': 'Harrison E. Livingstone',
#   'categories': 'History'},
#  {'title': "CliffsNotes on Flaubert's Madame Bovary",
#   'authors': 'James L. Roberts',
#   'categories': 'Literary Criticism'},
#  {'title': 'We Were the Rats',
#   'authors': 'Lawson Glassop',
#   'categories': 'Tobruk, Battles of, 1941-1942'},
#  {'title': 'Fourth of July mice',
#   'authors': 'Bethany Roberts',
#   'categories': 'Music'},
#  {'title': 'The Rosetta Codex',
#   'authors': 'Richard Paul Russo',
#   'categories': 'Fiction'},
#  {'title': 'Travels in the Scriptorium',
#   'authors': 'Paul Auster',
#   'categories': 'Fiction'},
#  {'title': 'The Red Badge of Courage',
#   'authors': 'Stephen Crane',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Visions from Nowhere',
#   'authors': 'William Arrow',
#   'categories': 'Science fiction'},
#  {'title': 'The 158-Pound Marriage',
#   'authors': 'John Irving',
#   'categories': 'Fiction'},
#  {'title': 'Season of the Machete',
#   'authors': 'James Patterson',
#   'categories': 'Fiction'},
#  {'title': 'The Body Artist',
#   'authors': 'Don DeLillo',
#   'categories': 'Fiction'},
#  {'title': "The Alchemist's Daughter",
#   'authors': 'Katharine McMahon',
#   'categories': 'Fiction'},
#  {'title': 'The Perfect Score',
#   'authors': 'Julie Kenner',
#   'categories': 'Fiction'},
#  {'title': 'The Campfire Collection',
#   'authors': 'Eric Martin',
#   'categories': 'Fiction'},
#  {'title': 'IMovie 4 & IDVD',
#   'authors': 'David Pogue',
#   'categories': 'Computers'},
#  {'title': 'Baby Einstein: What Does Violet See? Raindrops and Puddles',
#   'authors': 'Julie Aigner-Clark',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Good Faith', 'authors': 'Jane Smiley', 'categories': 'Fiction'},
#  {'title': 'The Love Artist',
#   'authors': 'Valerie Parv',
#   'categories': 'Fiction'},
#  {'title': 'D. B.', 'authors': 'Elwood Reid', 'categories': 'Fiction'},
#  {'title': 'Serenissima', 'authors': 'Erica Jong', 'categories': 'Fiction'},
#  {'title': "Girls' Night in",
#   'authors': 'Jessica Adams;Chris Manby;Fiona Walker',
#   'categories': 'American fiction'},
#  {'title': 'Firefly', 'authors': 'Piers Anthony', 'categories': 'Fiction'},
#  {'title': 'The Egyptologist',
#   'authors': 'Arthur Phillips',
#   'categories': 'Americans'},
#  {'title': 'Andrew Carnegie and the Rise of Big Business',
#   'authors': 'Harold C. Livesay',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Persuasive Communication',
#   'authors': 'James Brian Stiff;Paul A. Mongeau',
#   'categories': 'Language Arts & Disciplines'},
#  {'title': 'On the Trail of Mary Queen of Scots',
#   'authors': 'J. Keith Cheetham',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Ransom',
#   'authors': 'Jay McInerney',
#   'categories': 'Kyoto (Japan)'},
#  {'title': 'Angel of the Outback',
#   'authors': 'Patricia Hickman',
#   'categories': 'Fiction'},
#  {'title': 'The Soloist',
#   'authors': 'Nicholas Christopher',
#   'categories': 'Fiction'},
#  {'title': 'Getting Results with Curriculum Mapping',
#   'authors': 'Heidi Hayes Jacobs',
#   'categories': 'Education'},
#  {'title': "The Mistress's Daughter",
#   'authors': 'A. M. Homes',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Voices From the Street',
#   'authors': 'Philip K. Dick',
#   'categories': 'Fiction'},
#  {'title': 'Fury', 'authors': 'Salman Rushdie', 'categories': 'Anger'},
#  {'title': 'Chosen But Free',
#   'authors': 'Norman L. Geisler',
#   'categories': 'Religion'},
#  {'title': 'Days', 'authors': 'Paul Bowles', 'categories': 'Fiction'},
#  {'title': 'Corroborating Evidence',
#   'authors': 'William T. Rasmussen',
#   'categories': 'True Crime'},
#  {'title': 'Sisters',
#   'authors': 'Charles Higham',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Wideacre', 'authors': 'Philippa Gregory', 'categories': 'Fiction'},
#  {'title': 'The Camera My Mother Gave Me',
#   'authors': 'Susanna Kaysen',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'No Dress Rehearsal',
#   'authors': 'Marian Keyes',
#   'categories': 'Adjustment (Psychology)'},
#  {'title': 'Conan and the Demons of Khitai',
#   'authors': 'Akira Yoshida;Paul Lee;Robert Ervin Howard;Pat Lee',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Mini-Manual of the Urban Guerrilla',
#   'authors': 'Carlos Marighella',
#   'categories': 'Political Science'},
#  {'title': 'The Wise Woman',
#   'authors': 'Philippa Gregory',
#   'categories': 'Great Britain'},
#  {'title': 'The Final Solution',
#   'authors': 'Michael Chabon',
#   'categories': 'Fiction'},
#  {'title': 'The Valkyries', 'authors': 'Paulo Coelho', 'categories': 'Angels'},
#  {'title': 'The Big Empty',
#   'authors': 'Norman Mailer;John Buffalo Mailer',
#   'categories': 'Literary Collections'},
#  {'title': 'The Valkyries',
#   'authors': 'Paulo Coelho',
#   'categories': 'Fiction'},
#  {'title': 'Godless',
#   'authors': 'Ann H. Coulter',
#   'categories': 'Political Science'},
#  {'title': 'Paper Money',
#   'authors': 'Ken Follett',
#   'categories': 'Conspiracies'},
#  {'title': 'Stupid White Men',
#   'authors': 'Michael Moore',
#   'categories': 'American wit and humor'},
#  {'title': 'Remind Me Again Why I Need A Man',
#   'authors': 'Claudia Carroll',
#   'categories': 'Fiction'},
#  {'title': 'Atlantic Shift',
#   'authors': 'Emily Barr',
#   'categories': 'Cellists'},
#  {'title': 'How to Make Money Like a Porn Star',
#   'authors': 'Neil Strauss;Bernard Chang',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'A Mulligan for Bobby Jobe',
#   'authors': 'Robert Cullen',
#   'categories': 'Fiction'},
#  {'title': 'Power of An Hour',
#   'authors': 'Dave Lakhani',
#   'categories': 'Business & Economics'},
#  {'title': 'Candy', 'authors': 'Mian Mian', 'categories': 'Fiction'},
#  {'title': 'The Fourth Hand',
#   'authors': 'John Irving',
#   'categories': 'Fiction'},
#  {'title': 'The Boat of Dreams',
#   'authors': 'Richard Preston',
#   'categories': 'Fiction'},
#  {'title': 'Self-made Man',
#   'authors': 'Norah Vincent',
#   'categories': 'Social Science'},
#  {'title': 'Talk to the Hand',
#   'authors': 'Lynne Truss',
#   'categories': 'Conduct of life'},
#  {'title': 'Seven Sunny Days',
#   'authors': 'Chris Manby',
#   'categories': 'Fiction'},
#  {'title': 'Bound in Blood',
#   'authors': 'David Thomas Lord',
#   'categories': 'Fiction'},
#  {'title': 'Planet of the Apes',
#   'authors': 'Ian Edginton;Paco Medina;Adrian Sibar',
#   'categories': 'Human-animal relationships'},
#  {'title': 'Treasure Box',
#   'authors': 'Orson Scott Card',
#   'categories': 'Fiction'},
#  {'title': 'Maggie, a Girl of the Streets and Other Short Fiction',
#   'authors': 'Stephen Crane',
#   'categories': 'Fiction'},
#  {'title': 'A Kin of Homecoming',
#   'authors': 'Brian Azzarello;Marcelo Frusin',
#   'categories': 'Fiction'},
#  {'title': 'My Perfect Life',
#   'authors': 'Dyan Sheldon',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Port Mungo',
#   'authors': 'Patrick McGrath',
#   'categories': 'Fiction'},
#  {'title': 'The Accidental Bodyguard',
#   'authors': 'Ann Major',
#   'categories': 'Fiction'},
#  {'title': 'Intuition', 'authors': 'Allegra Goodman', 'categories': 'Fiction'},
#  {'title': 'Story of O', 'authors': 'Pauline Réage', 'categories': 'Fiction'},
#  {'title': 'Limitations', 'authors': 'Scott Turow', 'categories': 'Fiction'},
#  {'title': 'Man Walks Into a Room',
#   'authors': 'Nicole Krauss',
#   'categories': 'Fiction'},
#  {'title': "Conqueror's Moon",
#   'authors': 'Julian May',
#   'categories': 'Fiction'},
#  {'title': 'Forbidden Love',
#   'authors': 'Kate William;Francine Pascal',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'My Movie Business',
#   'authors': 'John Irving',
#   'categories': 'Cider house rules. (Motion picture)'},
#  {'title': 'The Ivory Tower',
#   'authors': 'Henry James',
#   'categories': 'Fiction'},
#  {'title': 'My Movie Business',
#   'authors': 'John Irving',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Reading Group',
#   'authors': 'Elizabeth Noble',
#   'categories': 'Fiction'},
#  {'title': 'Confessions of a Teenage Drama Queen',
#   'authors': 'Dyan Sheldon',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Deception', 'authors': 'Philip Roth', 'categories': 'Adultery'},
#  {'title': 'Zombie', 'authors': 'Joyce Carol Oates', 'categories': 'Fiction'},
#  {'title': 'Across the River and Into the Trees',
#   'authors': 'Ernest Hemingway',
#   'categories': 'Fiction'},
#  {'title': 'The Stone Fey',
#   'authors': 'Robin McKinley',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Catching Alice',
#   'authors': 'Clare Naylor',
#   'categories': 'Fiction'},
#  {'title': '浅草紅団', 'authors': 'Yasunari Kawabata', 'categories': 'Fiction'},
#  {'title': 'The Church in Emerging Culture',
#   'authors': 'Andy Crouch',
#   'categories': 'Religion'},
#  {'title': 'The Dark Arena', 'authors': 'Mario Puzo', 'categories': 'Fiction'},
#  {'title': "Your Best Friend's Boyfriend",
#   'authors': 'J. E. Bright',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Son of Superman',
#   'authors': 'Howard V. Chaykin;David Tischman',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Evening', 'authors': 'Susan Minot', 'categories': 'Fiction'},
#  {'title': "Harm's Way",
#   'authors': 'Elizabeth Stewart',
#   'categories': 'Fiction'},
#  {'title': 'The Terminal Man',
#   'authors': 'Michael Crichton',
#   'categories': 'Fiction'},
#  {'title': 'The Sunday Philosophy Club',
#   'authors': 'Alexander McCall Smith',
#   'categories': 'Fiction'},
#  {'title': 'Good as Gold',
#   'authors': 'Joseph Heller',
#   'categories': 'Fiction'},
#  {'title': 'The Halloween Man',
#   'authors': 'Douglas Clegg',
#   'categories': 'Fiction'},
#  {'title': 'Control Freak',
#   'authors': 'Francine Pascal',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Dead Babies', 'authors': 'Martin Amis', 'categories': 'Fiction'},
#  {'title': 'Assassinating Shakespeare',
#   'authors': 'Thomas Goltz',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Nightmare House',
#   'authors': 'Douglas Clegg',
#   'categories': 'Fiction'},
#  {'title': 'Boomers, Xers, and Other Strangers',
#   'authors': 'Rick Hicks;Kathy Hicks',
#   'categories': 'Social Science'},
#  {'title': 'I Should be Extremely Happy in Your Company',
#   'authors': 'Brian Hall',
#   'categories': 'Fiction'},
#  {'title': 'Jungle Love Level 5',
#   'authors': 'Margaret Johnson',
#   'categories': 'Foreign Language Study'},
#  {'title': 'Matters of Choice',
#   'authors': 'Noah Gordon',
#   'categories': 'Fiction'},
#  {'title': 'The Cloud Atlas',
#   'authors': 'Liam Callanan',
#   'categories': 'Fiction'},
#  {'title': 'Starting Over',
#   'authors': 'Francine Pascal',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Echo Maker',
#   'authors': 'Richard Powers',
#   'categories': 'Fiction'},
#  {'title': 'The Trial of Queen Caroline',
#   'authors': 'Jane Robins',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Changeling Storytellers Guide',
#   'authors': 'Mark Hunter;Nancy Schultz-Yetter;Steve Kenson;Ian Lemke;Nicky Rea',
#   'categories': 'Games'},
#  {'title': 'The Man Who Loved Jane Austen',
#   'authors': "Sally Smith O'Rourke",
#   'categories': 'Fiction'},
#  {'title': 'Doctor Who Short Trips: Repercussions',
#   'authors': 'Gary Russell',
#   'categories': 'Fiction'},
#  {'title': 'Through a Brazen Mirror',
#   'authors': 'Delia Sherman',
#   'categories': 'Fiction'},
#  {'title': 'Zizek', 'authors': 'Sarah Kay', 'categories': 'Social Science'},
#  {'title': 'Heat', 'authors': 'William Goldman', 'categories': 'Fiction'},
#  {'title': 'Phantoms',
#   'authors': 'Martin Harry Greenberg;Rosalind M. Greenberg',
#   'categories': 'Fiction'},
#  {'title': 'Posing for Portrait Photography',
#   'authors': 'Jeff Smith',
#   'categories': 'Photography'},
#  {'title': 'Blackmailed Into Bed',
#   'authors': 'Heidi Betts',
#   'categories': 'Fiction'},
#  {'title': 'Kiffe Kiffe Tomorrow',
#   'authors': 'Faïza Guène;Sarah Adams',
#   'categories': 'Fiction'},
#  {'title': 'Nathaniel Hawthorne, The Scarlet Letter',
#   'authors': 'Nathaniel Hawthorne',
#   'categories': 'Literary Criticism'},
#  {'title': 'Marilyn Manson',
#   'authors': 'Kurt Reighley',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Scarlet Letter',
#   'authors': 'Nathaniel Hawthorne',
#   'categories': 'Study Aids'},
#  {'title': 'Yeats is Dead!',
#   'authors': "Joseph O'Connor",
#   'categories': 'Comedy'},
#  {'title': 'The Scarlet Letter',
#   'authors': 'Nathaniel Hawthorne;Seymour Lee Gross',
#   'categories': 'Adultery'},
#  {'title': 'Shakespeare Alive!',
#   'authors': 'Joseph Papp;Elizabeth Kirkland',
#   'categories': 'Drama'},
#  {'title': 'CliffsComplete The Scarlet Letter',
#   'authors': 'Nathaniel Hawthorne',
#   'categories': 'Fiction'},
#  {'title': 'Stern Men',
#   'authors': 'Elizabeth Gilbert',
#   'categories': 'Fiction'},
#  {'title': 'The Coming Economic Collapse',
#   'authors': 'Stephen Leeb;Glen Strathy',
#   'categories': 'Business & Economics'},
#  {'title': 'The Scarlet Letter',
#   'authors': 'Nathaniel Hawthorne;Margaret Brantley',
#   'categories': 'Fiction'},
#  {'title': 'Homebody', 'authors': 'Orson Scott Card', 'categories': 'Fiction'},
#  {'title': 'The Mimic Men',
#   'authors': 'V. S. Naipaul',
#   'categories': 'British'},
#  {'title': 'Plato, Not Prozac!',
#   'authors': 'Lou Marinoff',
#   'categories': 'Philosophy'},
#  {'title': 'Man Crazy',
#   'authors': 'Joyce Carol Oates',
#   'categories': 'Fiction'},
#  {'title': 'The Discomfort Zone',
#   'authors': 'Jonathan Franzen',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Coming of the Fairies',
#   'authors': 'Arthur Conan Doyle',
#   'categories': 'Fiction'},
#  {'title': 'Hard Sell', 'authors': 'Piers Anthony', 'categories': 'Fiction'},
#  {'title': 'Inside the Mind of Gideon Rayburn',
#   'authors': 'Sarah Miller',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'After the Mourning',
#   'authors': 'Barbara Nadel',
#   'categories': 'Fiction'},
#  {'title': 'Blubberina',
#   'authors': 'Jahnna N. Malcolm',
#   'categories': 'Ballet'},
#  {'title': 'Who Needs Greek?',
#   'authors': 'Simon Goldhill',
#   'categories': 'History'},
#  {'title': 'ADHD in Adulthood',
#   'authors': 'Margaret Weiss;Lily Trokenberg Hechtman;Gabrielle Weiss',
#   'categories': 'Medical'},
#  {'title': 'El Paso', 'authors': 'Matt Braun', 'categories': 'Fiction'},
#  {'title': "There's No Toilet Paper... on the Road Less Traveled",
#   'authors': 'Doug Lansky',
#   'categories': 'Travel'},
#  {'title': 'Crucifix Lane',
#   'authors': 'Kate Mosse',
#   'categories': 'London (England)'},
#  {'title': 'The Dig',
#   'authors': 'Alan Dean Foster;Sean Clark',
#   'categories': 'Interplanetary voyages'},
#  {'title': 'Ready Or Not',
#   'authors': 'Meg Cabot',
#   'categories': 'Large print books'},
#  {'title': "CliffsNotes on Voltaire's Candide",
#   'authors': 'Francois Marie Arouet;James K. Lowers',
#   'categories': 'Literary Criticism'},
#  {'title': "Baby's Animal Friends",
#   'authors': 'Phoebe Dunn',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Love @ First Site',
#   'authors': 'Jane Moore',
#   'categories': 'Fiction'},
#  {'title': 'The Hunters',
#   'authors': 'Claire Messud',
#   'categories': 'American fiction'},
#  {'title': "All the King's Men",
#   'authors': 'L. David Allen;Robert H. Lynn',
#   'categories': 'Literary Criticism'},
#  {'title': 'Attack of the Jaguar',
#   'authors': 'M. A. Harvey',
#   'categories': 'Juvenile Fiction'},
#  {'title': "CliffsNotes on Wiesel's Night",
#   'authors': 'Maryam Riess',
#   'categories': 'Literary Criticism'},
#  {'title': 'Lord Malquist and Mr. Moon',
#   'authors': 'Tom Stoppard',
#   'categories': 'Fiction'},
#  {'title': 'At Risk',
#   'authors': 'Patricia Daniels Cornwell',
#   'categories': 'Fiction'},
#  {'title': 'The Italian Girl',
#   'authors': 'Patricia Hall',
#   'categories': 'Fiction'},
#  {'title': 'Kid Eternity',
#   'authors': 'Grant Morrison;Duncan Fegredo',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Moods', 'authors': 'Louisa May Alcott', 'categories': 'Fiction'},
#  {'title': 'The Spy who Loved Me',
#   'authors': 'Ian Fleming',
#   'categories': 'Adirondack Mountains (N.Y.)'},
#  {'title': 'City of God',
#   'authors': 'E. L. Doctorow',
#   'categories': 'Fiction'},
#  {'title': 'I Am Charlotte Simmons',
#   'authors': 'Tom Wolfe',
#   'categories': 'Fiction'},
#  {'title': 'Saga of the Sandman',
#   'authors': 'Tom DeFalco',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'South Park and Philosophy',
#   'authors': 'Robert Arp',
#   'categories': 'Philosophy'},
#  {'title': 'American Dragons',
#   'authors': 'Laurence Yep',
#   'categories': 'Juvenile Fiction'},
#  {'title': "H.G. Wells' Floor Games",
#   'authors': 'H. G. Wells;Barbara A. Turner',
#   'categories': 'Games & Activities'},
#  {'title': 'Bedded Then Wed',
#   'authors': 'Heidi Betts',
#   'categories': 'Fiction'},
#  {'title': 'Santa Cruise',
#   'authors': 'Mary Higgins Clark;Carol Higgins Clark',
#   'categories': 'Fiction'},
#  {'title': 'The Dead Beat',
#   'authors': 'Marilyn Johnson',
#   'categories': 'Social Science'},
#  {'title': 'Anatomy of a Boyfriend',
#   'authors': 'Daria Snadowsky',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Comfort of Strangers',
#   'authors': 'Ian McEwan',
#   'categories': 'Fiction'},
#  {'title': "Aristophanes' Acharnians",
#   'authors': 'Aristophanes;Jeffrey Henderson',
#   'categories': 'Drama'},
#  {'title': 'The Real Jimmy Carter',
#   'authors': 'Steven F. Hayward',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Clown Girl', 'authors': 'Monica Drake', 'categories': 'Fiction'},
#  {'title': 'Shopgirl', 'authors': 'Steve Martin', 'categories': 'Fiction'},
#  {'title': 'Mission Possible',
#   'authors': 'Ken Blanchard;Terry Waghorn',
#   'categories': 'Business & Economics'},
#  {'title': 'Undertaker of the Mind',
#   'authors': 'Jonathan Andrews;Andrew T. Scull',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Double Fold',
#   'authors': 'Nicholson Baker',
#   'categories': 'Language Arts & Disciplines'},
#  {'title': "The Dive from Clausen's Pier",
#   'authors': 'Ann Packer',
#   'categories': 'Fiction'},
#  {'title': 'Tono-Bungay', 'authors': 'H.G. Wells', 'categories': 'Fiction'},
#  {'title': "The Porcelain Dove, Or, Constancy's Reward",
#   'authors': 'Delia Sherman',
#   'categories': 'Fiction'},
#  {'title': 'A Long Way Down',
#   'authors': 'Nick Hornby',
#   'categories': 'Fiction'},
#  {'title': 'The Abandoned',
#   'authors': 'Douglas Clegg',
#   'categories': 'Fiction'},
#  {'title': 'A Mistress For The Taking',
#   'authors': 'Annie West',
#   'categories': 'Fiction'},
#  {'title': 'Running Dog', 'authors': 'Don DeLillo', 'categories': 'Fiction'},
#  {'title': 'Radio On',
#   'authors': 'Sarah Vowell',
#   'categories': 'Literary Collections'},
#  {'title': "Bill Bryson's African Diary",
#   'authors': 'Bill Bryson',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Beowulf', 'authors': 'Burton Raffel', 'categories': 'Fiction'},
#  {'title': 'Beowulf', 'authors': 'Seamus Heaney', 'categories': 'Beowulf'},
#  {'title': 'Ox', 'authors': 'Piers Anthony', 'categories': 'Fiction'},
#  {'title': 'Empire', 'authors': 'Orson Scott Card', 'categories': 'Fiction'},
#  {'title': 'Americana', 'authors': 'Don DeLillo', 'categories': 'Fiction'},
#  {'title': 'The Hidden Hand',
#   'authors': 'Carroll John Daly',
#   'categories': 'Fiction'},
#  {'title': 'The White Masai',
#   'authors': 'Corinne Hofmann',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Saving Fish from Drowning',
#   'authors': 'Amy Tan',
#   'categories': 'Fiction'},
#  {'title': 'Africa South of the Sahara, Second Edition',
#   'authors': 'Robert F. Stock;Robert Stock',
#   'categories': 'History'},
#  {'title': 'The Waiting Sands',
#   'authors': 'Susan Howatch',
#   'categories': 'Fiction'},
#  {'title': 'The Classic Ten',
#   'authors': 'Nancy MacDonell Smith;Nancy MacDonell',
#   'categories': 'Design'},
#  {'title': 'Beowulf',
#   'authors': 'Howell D. Chickering',
#   'categories': 'Literary Criticism'},
#  {'title': 'The Eyes of Heisenberg',
#   'authors': 'Frank Herbert',
#   'categories': 'Fiction'},
#  {'title': 'Thumbsucker', 'authors': 'Walter Kirn', 'categories': 'Fiction'},
#  {'title': 'The South Beach Diet',
#   'authors': 'Arthur Agatston',
#   'categories': 'Health & Fitness'},
#  {'title': 'Mystery Play',
#   'authors': 'Grant Morrison;Jon J. Muth',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Data Structures and Abstractions with Java',
#   'authors': 'Frank M. Carrano',
#   'categories': 'Computers'},
#  {'title': 'Blood Moon Over Britain',
#   'authors': 'Morag McKendrick Pippin',
#   'categories': 'Fiction'},
#  {'title': 'Enslaved by Ducks',
#   'authors': 'Bob Tarte',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Girl Meets Ape',
#   'authors': 'Chris Manby',
#   'categories': 'Animal sanctuaries'},
#  {'title': 'Naked Lunch',
#   'authors': 'William S. Burroughs',
#   'categories': 'Alienation (Social psychology)'},
#  {'title': 'The Fish Kisser',
#   'authors': 'James Hawkins',
#   'categories': 'Fiction'},
#  {'title': 'Summer Crossing',
#   'authors': 'Truman Capote;Alan U. Schwartz',
#   'categories': 'Fiction'},
#  {'title': 'Diabolo',
#   'authors': 'Kaoru Ohashi;Kei Kusunoki',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': "Han'guk-sik Sarang",
#   'authors': 'J. Torres',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'The Turn of the Screw',
#   'authors': 'Henry James;Deborah Esch;Jonathan Warren',
#   'categories': 'Fiction'},
#  {'title': 'The Hollow Man',
#   'authors': 'Dan Simmons',
#   'categories': 'Fiction'},
#  {'title': 'The Nuclear Age',
#   'authors': "Tim O'Brien",
#   'categories': 'Fiction'},
#  {'title': 'Minion', 'authors': 'L. A. Banks', 'categories': 'Fiction'},
#  {'title': 'Mr. Maybe', 'authors': 'Jane Green', 'categories': 'Fiction'},
#  {'title': "Naomi and Ely's No Kiss List",
#   'authors': 'Rachel Cohn;David Levithan',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Pursuit of History',
#   'authors': 'John Tosh;Sean Lang',
#   'categories': 'History'},
#  {'title': 'Emotionally Weird',
#   'authors': 'Kate Atkinson',
#   'categories': 'Fiction'},
#  {'title': 'The Little Friend',
#   'authors': 'Donna Tartt',
#   'categories': 'Brothers'},
#  {'title': 'Blood on the Moon',
#   'authors': 'James Ellroy',
#   'categories': 'Fiction'},
#  {'title': 'The White Castle',
#   'authors': 'Orhan Pamuk',
#   'categories': 'Civil law'},
#  {'title': 'My Century',
#   'authors': 'Günter Grass',
#   'categories': 'History, Modern'},
#  {'title': 'Alone in the Crowd',
#   'authors': 'Francine Pascal',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Cuba 15',
#   'authors': 'Nancy Osa',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The New Jessica',
#   'authors': 'Francine Pascal',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Blood Moon Over Bengal',
#   'authors': 'Morag McKendrick Pippin',
#   'categories': 'Fiction'},
#  {'title': 'Once Upon a Gulf Coast Summer',
#   'authors': 'Susan Oliver',
#   'categories': 'Fiction'},
#  {'title': 'Country of Origin: A Novel',
#   'authors': 'Don Lee',
#   'categories': 'Fiction'},
#  {'title': 'Real Rule of Four',
#   'authors': 'Joscelyn Godwin',
#   'categories': 'History'},
#  {'title': 'The Portrait', 'authors': 'Iain Pears', 'categories': 'Fiction'},
#  {'title': 'Secrets',
#   'authors': 'Francine Pascal;Kate William',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Outlander',
#   'authors': 'Timothy Truman;Tom Raney',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Surfacing', 'authors': 'Margaret Atwood', 'categories': 'Fiction'},
#  {'title': 'Julie, Or, The New Heloise',
#   'authors': 'Jean-Jacques Rousseau;Roger D. Masters;Christopher Kelly',
#   'categories': 'Literary Criticism'},
#  {'title': 'Before You Know Kindness',
#   'authors': 'Chris Bohjalian',
#   'categories': 'Fiction'},
#  {'title': 'Stamboul Train',
#   'authors': 'Graham Greene',
#   'categories': 'Fiction'},
#  {'title': 'Lovelock',
#   'authors': 'Orson Scott Card;Kathryn H. Kidd',
#   'categories': 'Fiction'},
#  {'title': 'The Wedding Night',
#   'authors': 'Jayne Ann Krentz',
#   'categories': 'Fiction'},
#  {'title': 'The Diezmo', 'authors': 'Rick Bass', 'categories': 'Fiction'},
#  {'title': "The Devil's Labyrinth",
#   'authors': 'John Saul',
#   'categories': 'Fiction'},
#  {'title': 'Legacy of the Darksword',
#   'authors': 'Margaret Weis;Tracy Hickman',
#   'categories': 'Fiction'},
#  {'title': 'The Crack in Space',
#   'authors': 'Philip K. Dick',
#   'categories': 'Fiction'},
#  {'title': 'Vision of Tarot',
#   'authors': 'Piers Anthony',
#   'categories': 'Fiction'},
#  {'title': 'Janet, My Mother, and Me',
#   'authors': 'William Murray',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Hard News', 'authors': 'Jeffery Deaver', 'categories': 'Fiction'},
#  {'title': '1001 Illuminated Initial Letters',
#   'authors': 'Owen Jones',
#   'categories': 'Design'},
#  {'title': 'What Would Machiavelli Do?',
#   'authors': 'Stanley Bing',
#   'categories': 'Humor'},
#  {'title': 'Glamorama',
#   'authors': 'Bret Easton Ellis',
#   'categories': 'Fiction'},
#  {'title': 'Bleachers', 'authors': 'John Grisham', 'categories': 'Death'},
#  {'title': 'Terraforming Earth',
#   'authors': 'Jack Williamson',
#   'categories': 'Fiction'},
#  {'title': 'The Unfortunate Miss Fortunes',
#   'authors': 'Jennifer Crusie;Eileen Dreyer;Anne Stuart',
#   'categories': 'Fiction'},
#  {'title': 'The Spy Who Barked',
#   'authors': 'George Edward Stanley',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Son of a Witch',
#   'authors': 'Gregory Maguire',
#   'categories': 'Fiction'},
#  {'title': 'Bright Purple',
#   'authors': 'Melody Carlson',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Simpsons and Philosophy',
#   'authors': 'William Irwin;Mark T. Conard;Aeon J. Skoble',
#   'categories': 'Performing Arts'},
#  {'title': 'Frankenstein',
#   'authors': 'Mary Shelley',
#   'categories': 'LITERARY CRITICISM'},
#  {'title': 'Parachutes & Kisses',
#   'authors': 'Erica Jong',
#   'categories': 'Fiction'},
#  {'title': "Hart's Hope",
#   'authors': 'Orson Scott Card',
#   'categories': 'Fiction'},
#  {'title': 'A Nose for Murder',
#   'authors': 'Lee Charles Kelley',
#   'categories': 'Fiction'},
#  {'title': 'Gone Bamboo',
#   'authors': 'Anthony Bourdain',
#   'categories': 'Assassins'},
#  {'title': 'Jukebox Queen Of Malta',
#   'authors': 'Nicholas Rinaldi',
#   'categories': 'Fiction'},
#  {'title': 'What a Scare, Jesse Bear',
#   'authors': 'Nancy White Carlstrom',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Running Away from Richard',
#   'authors': 'Chris Manby',
#   'categories': 'Actresses'},
#  {'title': 'Steamed',
#   'authors': 'Jessica Conant-Park;Susan Conant',
#   'categories': 'Fiction'},
#  {'title': "Baumgartner's Bombay",
#   'authors': 'Anita Desai',
#   'categories': 'Fiction'},
#  {'title': 'Lost Boy, Lost Girl',
#   'authors': 'Peter Straub',
#   'categories': 'Fiction'},
#  {'title': 'Sgt. Rock',
#   'authors': 'Joe Kubert',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Black Coffee',
#   'authors': 'Agatha Christie',
#   'categories': 'Fiction'},
#  {'title': 'Miss Wyoming',
#   'authors': 'Douglas Coupland',
#   'categories': 'Actors'},
#  {'title': 'Paint it Black',
#   'authors': 'Janet Fitch',
#   'categories': 'Fiction'},
#  {'title': 'Shadows and Wind',
#   'authors': 'Robert Templer',
#   'categories': 'History'},
#  {'title': '7 Steps to Midnight',
#   'authors': 'Richard Matheson',
#   'categories': 'Fiction'},
#  {'title': "Jessica's Bad Idea",
#   'authors': 'Jamie Suzanne;Francine Pascal',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Adventures of Baron Munchausen, the Screenplay',
#   'authors': 'Charles McKeown;Terry Gilliam',
#   'categories': 'Performing Arts'},
#  {'title': 'Slaughterhouse Blues',
#   'authors': 'Donald D. Stull;Michael J. Broadway',
#   'categories': 'Social Science'},
#  {'title': 'Cherries in the Snow',
#   'authors': 'Emma Forrest',
#   'categories': 'Cosmetics industry'},
#  {'title': 'The Art of Loving',
#   'authors': 'Eiki Eiki;Yukine Honami',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Five Patients',
#   'authors': 'Michael Crichton',
#   'categories': 'Social Science'},
#  {'title': 'Man and Wife', 'authors': 'Tony Parsons', 'categories': 'Fiction'},
#  {'title': 'Skipping Christmas',
#   'authors': 'John Grisham',
#   'categories': 'Christmas'},
#  {'title': 'The Guy Not Taken',
#   'authors': 'Jennifer Weiner',
#   'categories': 'Fiction'},
#  {'title': 'Who are You?',
#   'authors': 'Malcolm Godwin',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'Star Trek: The Next Generation: Nightshade',
#   'authors': 'Laurell K. Hamilton',
#   'categories': 'Fiction'},
#  {'title': 'Legends, Lies & Cherished Myths of World History',
#   'authors': 'Richard Shenkman',
#   'categories': 'History'},
#  {'title': 'Answered Prayers',
#   'authors': 'Truman Capote',
#   'categories': 'Authors'},
#  {'title': "Bridget Jones's Guide to Life",
#   'authors': 'Helen Fielding',
#   'categories': 'Fiction'},
#  {'title': 'Eastern Standard Tribe',
#   'authors': 'Cory Doctorow',
#   'categories': 'Fiction'},
#  {'title': 'The Canterbury Tales',
#   'authors': 'Geoffrey Chaucer',
#   'categories': 'Poetry'},
#  {'title': 'The Crazed',
#   'authors': 'Ha Jin',
#   'categories': 'Cerebrovascular disease'},
#  {'title': 'Beowulf', 'authors': 'Robert Nye', 'categories': 'Fiction'},
#  {'title': 'Does Anybody Have a Problem with That?',
#   'authors': 'Bill Maher',
#   'categories': 'Humor'},
#  {'title': "CliffsNotes on Dickens' A Tale of Two Cities",
#   'authors': 'Marie Kalil',
#   'categories': 'Literary Criticism'},
#  {'title': 'Hardball',
#   'authors': 'George Stalk;Robert Lachenauer;John Butman',
#   'categories': 'Business & Economics'},
#  {'title': 'The Canterbury Tales',
#   'authors': 'Geoffrey Chaucer;David Wright',
#   'categories': 'Poetry'},
#  {'title': 'Moby-Dick', 'authors': 'Herman Melville', 'categories': 'Fiction'},
#  {'title': 'Moby-Dick, Or, The Whale',
#   'authors': 'Herman Melville',
#   'categories': 'Fiction'},
#  {'title': 'The Canterbury Tales',
#   'authors': 'Geoffrey Chaucer',
#   'categories': 'Poetry'},
#  {'title': 'Everything Bad is Good for You',
#   'authors': 'Steven Johnson',
#   'categories': 'Psychology'},
#  {'title': 'Mischief', 'authors': 'Douglas Clegg', 'categories': 'Fiction'},
#  {'title': 'Next', 'authors': 'Michael Crichton', 'categories': 'Fiction'},
#  {'title': "Ratner's Star",
#   'authors': 'Don DeLillo',
#   'categories': 'Life on other planets'},
#  {'title': 'Strata',
#   'authors': 'Terry Pratchett',
#   'categories': 'English fiction'},
#  {'title': 'Naked Came the Manatee',
#   'authors': 'Carl Hiaasen;Dave Barry;Elmore Leonard',
#   'categories': 'Fiction'},
#  {'title': 'The Swarm War',
#   'authors': 'Troy Denning',
#   'categories': 'Fiction'},
#  {'title': 'What Went Wrong?',
#   'authors': 'Bernard Lewis',
#   'categories': 'History'},
#  {'title': 'Popcorn', 'authors': 'Ben Elton', 'categories': 'Criminals'},
#  {'title': 'The Ultimate Time Machine',
#   'authors': 'Joseph McMoneagle',
#   'categories': 'Body, Mind & Spirit'},
#  {'title': 'The Moth Diaries',
#   'authors': 'Rachel Klein',
#   'categories': 'Boarding schools'},
#  {'title': 'Best Ghost and Horror Stories',
#   'authors': 'Bram Stoker;Richard Dalby;Stefan R. Dziemianowicz;S. T. Joshi',
#   'categories': 'Fiction'},
#  {'title': 'The Science of Stephen King',
#   'authors': 'Lois H. Gresh;Robert Weinberg',
#   'categories': 'Literary Criticism'},
#  {'title': 'Blame it on the Blackout',
#   'authors': 'Heidi Betts',
#   'categories': 'Fiction'},
#  {'title': 'Deep and Meaningful Diaries from Planet Janet',
#   'authors': 'Dyan Sheldon',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'A Couple of April Fools',
#   'authors': 'Gregory Maguire',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Essentials of American Government',
#   'authors': "Karen O'Connor;Larry J. Sabato",
#   'categories': 'Political Science'},
#  {'title': 'Shampoo Planet',
#   'authors': 'Douglas Coupland',
#   'categories': 'Fiction'},
#  {'title': 'Courageous Faith Through the Year',
#   'authors': 'Bill Hybels',
#   'categories': 'Religion'},
#  {'title': 'Tales of Magick',
#   'authors': 'Phil Brucato;Aaron Rosenberg',
#   'categories': 'Fiction'},
#  {'title': 'Are We There Yet?',
#   'authors': 'David Levithan',
#   'categories': 'Juvenile Fiction'},
#  {'title': "CliffsNotes on Dostoevsky's The Brothers Karamazov",
#   'authors': 'James L. Roberts;Gary Carey',
#   'categories': 'Literary Criticism'},
#  {'title': 'The John Adams Reader',
#   'authors': 'Thomas Robert May',
#   'categories': 'Music'},
#  {'title': 'The Virtue of Selfishness',
#   'authors': 'Ayn Rand;Nathaniel Branden',
#   'categories': 'Philosophy'},
#  {'title': 'The World of Jules Verne',
#   'authors': 'Gonzague Saint Bris',
#   'categories': 'Fiction'},
#  {'title': 'The Night Awakens',
#   'authors': 'Mary Higgins Clark',
#   'categories': 'Fiction'},
#  {'title': "CliffsNotes On Joyce's Dubliners",
#   'authors': 'Adam Sexton',
#   'categories': 'Literary Criticism'},
#  {'title': "Fodor's Amsterdam",
#   'authors': "Fodor's Travel Publications, Inc. Staff",
#   'categories': 'Travel'},
#  {'title': 'eBay For Dummies',
#   'authors': 'Marsha Collier',
#   'categories': 'Business & Economics'},
#  {'title': 'Sins of a Shaker Summer',
#   'authors': 'Deborah Woodworth',
#   'categories': 'Fiction'},
#  {'title': 'Death of a Salesman',
#   'authors': 'Arthur Miller',
#   'categories': 'American drama'},
#  {'title': 'Floaters', 'authors': 'Joseph Wambaugh', 'categories': 'Fiction'},
#  {'title': 'The Zero', 'authors': 'Jess Walter', 'categories': 'Fiction'},
#  {'title': 'Death of a Salesman',
#   'authors': 'Gerald Clifford Weales',
#   'categories': 'Drama'},
#  {'title': 'Like a Charm',
#   'authors': 'Karin Slaughter',
#   'categories': 'Bracelets'},
#  {'title': 'International Plumbing Code 2006',
#   'authors': 'International Code Council',
#   'categories': 'Technology & Engineering'},
#  {'title': 'Ocean Star Express',
#   'authors': 'Mark Haddon;Peter Sutton',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Thriller', 'authors': 'James Patterson', 'categories': 'Fiction'},
#  {'title': 'Childhood Shadows',
#   'authors': 'Mary Pacios',
#   'categories': 'True Crime'},
#  {'title': 'American Tragedy',
#   'authors': 'David E. Kaiser',
#   'categories': 'History'},
#  {'title': 'Not Just a Pretty Face',
#   'authors': 'Molly Lee',
#   'categories': 'Antiques & Collectibles'},
#  {'title': "Teaching the World's Children",
#   'authors': 'Mary Ashworth;Patricia Wakefield',
#   'categories': 'Education'},
#  {'title': 'International Codes',
#   'authors': 'International Code Council',
#   'categories': 'Building laws'},
#  {'title': 'Feeding the Future',
#   'authors': 'Andrew Heintzman;Evan Solomon',
#   'categories': 'Social Science'},
#  {'title': 'The Rana Look',
#   'authors': 'Sandra Brown',
#   'categories': 'Fiction'},
#  {'title': 'Death of a Salesman',
#   'authors': 'Arthur Miller',
#   'categories': 'Fiction'},
#  {'title': 'Strange Bedpersons',
#   'authors': 'Jennifer Crusie',
#   'categories': 'Fiction'},
#  {'title': 'Hello! Is That Grandma?',
#   'authors': 'Ian Whybrow;Deborah Allwright',
#   'categories': "Children's stories"},
#  {'title': 'Worlds', 'authors': 'Joe Haldeman', 'categories': 'Fiction'},
#  {'title': 'The Family Way',
#   'authors': 'Tony Parsons',
#   'categories': 'Parenthood'},
#  {'title': 'Echoes of the Marseillaise',
#   'authors': 'Eric J. Hobsbawm',
#   'categories': 'History'},
#  {'title': 'Fugitives and Refugees',
#   'authors': 'Chuck Palahniuk',
#   'categories': 'Travel'},
#  {'title': 'The Virtues of Aging',
#   'authors': 'Jimmy Carter',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Sea', 'authors': 'John Banville', 'categories': 'Fiction'},
#  {'title': 'Does Anything Eat Wasps?',
#   'authors': 'New Scientist',
#   'categories': 'Humor'},
#  {'title': 'Quivers',
#   'authors': 'Robin Quivers',
#   'categories': 'African Americans in radio broadcasting'},
#  {'title': 'Strong Motion',
#   'authors': 'Jonathan Franzen',
#   'categories': 'Boston (Mass.)'},
#  {'title': 'Sweet 18',
#   'authors': 'Francine Pascal',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Pirates Laffite',
#   'authors': 'William C. Davis',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Dead Air',
#   'authors': 'Iain Banks',
#   'categories': 'London (England)'},
#  {'title': 'The Good Fairies of New York',
#   'authors': 'Martin Millar',
#   'categories': 'Fiction'},
#  {'title': 'Vice', 'authors': 'Jane Feather', 'categories': 'Fiction'},
#  {'title': "Vulcan's Hammer",
#   'authors': 'Philip K. Dick',
#   'categories': 'Fiction'},
#  {'title': 'Star Wars: Empire Volume 5',
#   'authors': 'Various',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'Starshield Sentinels',
#   'authors': 'Margaret Weis;Tracy Hickman',
#   'categories': 'Fiction'},
#  {'title': 'Rat Bastards',
#   'authors': 'John Shea',
#   'categories': 'Biography & Autobiography'},
#  {'title': "Rose of No Man's Land",
#   'authors': 'Michelle Tea',
#   'categories': 'Fiction'},
#  {'title': "Kevin Trudeau's Mega Memory",
#   'authors': 'Kevin Trudeau',
#   'categories': 'Self-Help'},
#  {'title': 'Gossip Girl #1',
#   'authors': 'Cecily von Ziegesar',
#   'categories': 'Young Adult Fiction'},
#  {'title': 'Daisy Miller and Other Stories',
#   'authors': 'Henry James',
#   'categories': 'Fiction'},
#  {'title': 'Someone Comes to Town, Someone Leaves Town',
#   'authors': 'Cory Doctorow',
#   'categories': 'Fiction'},
#  {'title': 'The Name of the World',
#   'authors': 'Denis Johnson',
#   'categories': 'College teachers'},
#  {'title': 'Belle Ruin', 'authors': 'Martha Grimes', 'categories': 'Fiction'},
#  {'title': 'Under The Duvet',
#   'authors': 'Marian Keyes',
#   'categories': 'Fiction'},
#  {'title': 'Quiver',
#   'authors': 'Stephanie Spinner',
# ...
#  {'title': 'Human Traces',
#   'authors': 'Sebastian Faulks',
#   'categories': 'Europe'},
#  {'title': 'Jack',
#   'authors': 'A. M. Homes',
#   'categories': 'Children of divorced parents'},
#  {'title': "Stephen King's Danse Macabre",
#   'authors': 'Stephen King',
#   'categories': 'Fiction'},
#  {'title': 'Shadows at Sunset',
#   'authors': 'Anne Stuart',
#   'categories': 'Fiction'},
#  {'title': 'What the Lady Wants',
#   'authors': 'Jennifer Crusie',
#   'categories': 'Fiction'},
#  {'title': 'The Disappointment Artist',
#   'authors': 'Jonathan Lethem',
#   'categories': 'Literary Collections'},
#  {'title': 'The Attraction',
#   'authors': 'Douglas Clegg',
#   'categories': 'Fiction'},
#  {'title': 'Micah. (Anita Blake',
#   'authors': 'Laurell K. Hamilton',
#   'categories': 'Blake, Anita (Fictitious character)'},
#  {'title': 'How the García Girls Lost Their Accents',
#   'authors': 'Julia Alvarez',
#   'categories': 'Fiction'},
#  {'title': 'Enduring Love',
#   'authors': 'Ian McEwan',
#   'categories': 'Accidents'},
#  {'title': 'The Greatest Sailing Stories Ever Told',
#   'authors': 'Christopher Caswell',
#   'categories': 'Sports & Recreation'},
#  {'title': 'You Shall Know Our Velocity!',
#   'authors': 'Dave Eggers',
#   'categories': 'Fiction'},
#  {'title': 'Camouflage',
#   'authors': 'Joe W. Haldeman',
#   'categories': 'Fiction'},
#  {'title': 'Dark Birthright',
#   'authors': 'Jeanne Treat',
#   'categories': 'History'},
#  {'title': 'The Wood Boy',
#   'authors': 'Raymond E. Feist;Sean J. Jordan;Tad Williams',
#   'categories': 'Comics & Graphic Novels'},
#  {'title': 'The Celestine Prophecy',
#   'authors': 'James Redfield',
#   'categories': 'Fiction'},
#  {'title': 'Baby Signing For Dummies',
#   'authors': 'Jennifer Watson',
#   'categories': 'Family & Relationships'},
#  {'title': 'The Invisible Man',
#   'authors': 'H. G. Wells;M. T. Anderson',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Anthem', 'authors': 'Ayn Rand', 'categories': 'Fiction'},
#  {'title': 'Spellbound', 'authors': 'Jane Green', 'categories': 'Fiction'},
#  {'title': 'The Invisible Man',
#   'authors': 'Herbert George Wells',
#   'categories': 'Fiction'},
#  {'title': 'The Doctor Is Sick',
#   'authors': 'Anthony Burgess',
#   'categories': 'Fiction'},
#  {'title': 'The Natural',
#   'authors': 'Bernard Malamud',
#   'categories': 'Fiction'},
#  {'title': 'The Beatles and Philosophy',
#   'authors': 'Michael Baur;Steven Baur',
#   'categories': 'Philosophy'},
#  {'title': 'Moral Disorder',
#   'authors': 'Margaret Atwood',
#   'categories': 'Fiction'},
#  {'title': 'Twister',
#   'authors': 'Michael Crichton;Anne-Marie Martin',
#   'categories': 'Motion picture plays'},
#  {'title': 'SeinLanguage', 'authors': 'Jerry Seinfeld', 'categories': 'Humor'},
#  {'title': 'The Secret Dreamworld of a Shopaholic',
#   'authors': 'Sophie Kinsella',
#   'categories': 'Finance, Personal'},
#  {'title': 'The Delta Star',
#   'authors': 'Joseph Wambaugh',
#   'categories': 'Fiction'},
#  {'title': 'Cheetah Girls #2: Shop in the Name of Love',
#   'authors': 'Deborah Gregory;Paul Mantell',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Awakening',
#   'authors': 'Kate Chopin;Margo Culley',
#   'categories': 'Fiction'},
#  {'title': 'Gloriana', 'authors': 'Michael Moorcock', 'categories': 'Fiction'},
#  {'title': 'The Other Woman',
#   'authors': "Ann O'Leary",
#   'categories': 'Fiction'},
#  {'title': 'Jean Rhys',
#   'authors': 'Carl Plasa',
#   'categories': 'Literary Criticism'},
#  {'title': 'Jemima J.', 'authors': 'Jane Green', 'categories': 'Fiction'},
#  {'title': 'Between the Acts',
#   'authors': 'Virginia Woolf',
#   'categories': 'Fiction'},
#  {'title': 'Son of the Mob: Hollywood Hustle',
#   'authors': 'Gordon Korman',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Dublin 4',
#   'authors': 'Maeve Binchy',
#   'categories': 'Domestic fiction'},
#  {'title': 'Dust', 'authors': 'Martha Grimes', 'categories': 'Fiction'},
#  {'title': 'Things Fall Apart',
#   'authors': 'Chinua Achebe;Sandra Widner',
#   'categories': 'Igbo (African people)'},
#  {'title': 'Party Shoes',
#   'authors': 'Noel Streatfeild',
#   'categories': "Children's stories"},
#  {'title': 'Code Orange',
#   'authors': 'Caroline B. Cooney',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Anesthesiology Review',
#   'authors': 'Ronald J. Faust;Roy F. Cucchiara',
#   'categories': 'Medical'},
#  {'title': 'The Road to Gandolfo',
#   'authors': 'Robert Ludlum',
#   'categories': 'Fiction'},
#  {'title': 'The Players of Gilean',
#   'authors': 'Margaret Weis;Tracy Hickman',
#   'categories': 'Fiction'},
#  {'title': 'Cider',
#   'authors': 'Annie Proulx;Lew Nichols',
#   'categories': 'Cooking'},
#  {'title': 'Haussmann, Or the Distinction',
#   'authors': 'Paul LaFarge',
#   'categories': 'Fiction'},
#  {'title': 'Lost Continents',
#   'authors': 'Lyon Sprague De Camp',
#   'categories': 'Social Science'},
#  {'title': 'Mysteries of Pittsburgh',
#   'authors': 'Michael Chabon',
#   'categories': 'Fiction'},
#  {'title': 'East is East',
#   'authors': 'T. Coraghessan Boyle',
#   'categories': 'Fiction'},
#  {'title': 'Love Beyond Reason',
#   'authors': 'Sandra Brown',
#   'categories': 'Fiction'},
#  {'title': 'Neptune Noir',
#   'authors': 'Rob Thomas;Leah Wilson',
#   'categories': 'Performing Arts'},
#  {'title': 'Mahatma Gandhi and His Myths',
#   'authors': 'Mark Shepard',
#   'categories': 'Political Science'},
#  {'title': 'Ballet Class Coloring Book',
#   'authors': 'John Green;Caroline Denzler',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Basics Illustration 01',
#   'authors': 'Mark Wigan',
#   'categories': 'Art'},
#  {'title': 'Confessions of a French Baker',
#   'authors': 'Peter Mayle;Gerard Auzet',
#   'categories': 'Cooking'},
#  {'title': 'The Drift House',
#   'authors': 'Dale Peck',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Night of the Long Shadows',
#   'authors': 'Paul Crilley',
#   'categories': 'Fiction'},
#  {'title': 'How Democratic is the American Constitution?',
#   'authors': 'Robert A. Dahl',
#   'categories': 'History'},
#  {'title': 'Under The Influence',
#   'authors': 'Preston Peet',
#   'categories': 'History'},
#  {'title': 'Sandworms of Dune',
#   'authors': 'Brian Herbert;Kevin J. Anderson',
#   'categories': 'Fiction'},
#  {'title': 'Sanctuary',
#   'authors': 'William Faulkner',
#   'categories': 'Fiction'},
#  {'title': 'The Great American Novel',
#   'authors': 'Philip Roth',
#   'categories': 'Fiction'},
#  {'title': 'The Short History of a Prince',
#   'authors': 'Jane Hamilton',
#   'categories': 'Ballet dancers'},
#  {'title': 'Dead Famous', 'authors': 'Ben Elton', 'categories': 'Fiction'},
#  {'title': "Ellora's Cavemen",
#   'authors': 'Elisa Adams;Sylvia Day;Anna J. Evans;Denise A. Agnew;B. J. McCall',
#   'categories': 'Fiction'},
#  {'title': "The Hedgehog, the Fox, and the Magister's Pox",
#   'authors': 'Stephen Jay Gould',
#   'categories': 'Science'},
#  {'title': 'The Awakening',
#   'authors': 'Kate Chopin',
#   'categories': 'Adultery'},
#  {'title': 'Crazy Lady!',
#   'authors': 'Jane Leslie Conly',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Anthonology', 'authors': 'Piers Anthony', 'categories': 'Fiction'},
#  {'title': 'The Names', 'authors': 'Don DeLillo', 'categories': 'Fiction'},
#  {'title': 'The Day of the Tempest',
#   'authors': 'Jean Rabe',
#   'categories': 'Fiction'},
#  {'title': 'The Santaroga Barrier',
#   'authors': 'Frank Herbert',
#   'categories': 'Fiction'},
#  {'title': 'Good-bye Stacey, Good-bye',
#   'authors': 'Ann M. Martin',
#   'categories': 'English language'},
#  {'title': 'Book of the Dead',
#   'authors': 'Patricia Daniels Cornwell',
#   'categories': 'Fiction'},
#  {'title': 'Hunters of Dune',
#   'authors': 'Brian Herbert;Kevin J. Anderson',
#   'categories': 'Fiction'},
#  {'title': 'Three Genres',
#   'authors': 'Stephen Minot',
#   'categories': 'Language Arts & Disciplines'},
#  {'title': 'The Love of the Last Tycoon',
#   'authors': 'F. Scott Fitzgerald',
#   'categories': 'Fiction'},
#  {'title': 'Star Trek Logs Five and Six',
#   'authors': 'Alan Dean Foster',
#   'categories': 'Fiction'},
#  {'title': 'The Au Pairs',
#   'authors': 'Melissa de la Cruz',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Zero Debt',
#   'authors': 'Lynnette Khalfani',
#   'categories': 'Business & Economics'},
#  {'title': 'Korean Short History',
#   'authors': 'James L. Stokesbury',
#   'categories': 'History'},
#  {'title': 'Cell', 'authors': 'Stephen King', 'categories': 'Fiction'},
#  {'title': 'A Complicated Kindness',
#   'authors': 'Miriam Toews',
#   'categories': 'Fiction'},
#  {'title': 'Slim to None',
#   'authors': 'Jennifer Hendricks',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Pilgrimage',
#   'authors': 'Paulo Coelho;Alan R. Clarke',
#   'categories': 'Fiction'},
#  {'title': 'Shroud', 'authors': 'John Banville', 'categories': 'Fiction'},
#  {'title': 'How to Think Theologically',
#   'authors': 'Howard W. Stone;James O. Duke',
#   'categories': 'Religion'},
#  {'title': "The Non-designer's Web Book",
#   'authors': 'Robin Williams;John Tollett',
#   'categories': 'Computers'},
#  {'title': 'The Box Man', 'authors': 'Kōbō Abe', 'categories': 'Fiction'},
#  {'title': 'The Function of Criticism',
#   'authors': 'Terry Eagleton',
#   'categories': 'Philosophy'},
#  {'title': 'The Making of a Philosopher',
#   'authors': 'Colin McGinn',
#   'categories': 'Philosophy'},
#  {'title': 'How to Read Literature Like a Professor',
#   'authors': 'Thomas C. Foster',
#   'categories': 'Literary Criticism'},
#  {'title': 'Isolde, Queen of the Western Isle',
#   'authors': 'Rosalind Miles',
#   'categories': 'Fiction'},
#  {'title': 'Trump',
#   'authors': 'Donald Trump',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'Athena', 'authors': 'John Banville', 'categories': 'Fiction'},
#  {'title': 'Ego & Hubris',
#   'authors': 'Harvey Pekar',
#   'categories': 'Biography & Autobiography'},
#  {'title': 'The Tortilla Curtain',
#   'authors': 'T. Coraghessan Boyle',
#   'categories': 'Fiction'},
#  {'title': 'Double Dealer',
#   'authors': 'Max Allan Collins',
#   'categories': 'Fiction'},
#  {'title': 'Present Tense', 'authors': 'L. A. Graf', 'categories': 'Fiction'},
#  {'title': "The Magician's Assistant",
#   'authors': 'Ann Patchett',
#   'categories': 'Fantasy fiction'},
#  {'title': 'Goodnight Nobody',
#   'authors': 'Jennifer Weiner',
#   'categories': 'Fiction'},
#  {'title': 'Z for Zachariah',
#   'authors': "Robert C. O'Brien",
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Love Overboard',
#   'authors': 'Janet Evanovich',
#   'categories': 'Fiction'},
#  {'title': "The Memory Keeper's Daughter",
#   'authors': 'Kim Edwards',
#   'categories': 'Fiction'},
#  {'title': 'You On A Diet',
#   'authors': 'M. D. Roizen (Michael F.);Michael F. Roizen',
#   'categories': 'Reducing diets'},
#  {'title': 'Boltzmon!',
#   'authors': 'William Sleator',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Philosophy For Dummies',
#   'authors': 'Tom Morris',
#   'categories': 'Philosophy'},
#  {'title': 'The Law of Enclosures',
#   'authors': 'Dale Peck',
#   'categories': 'Fiction'},
#  {'title': 'The Secret Sister',
#   'authors': 'Elizabeth Lowell',
#   'categories': 'Fiction'},
#  {'title': 'The Sillymarillion',
#   'authors': 'D. R. Lloyd',
#   'categories': 'Fiction'},
#  {'title': 'Avalanche',
#   'authors': 'Arthur Roth',
#   'categories': 'Adult education'},
#  {'title': 'A Secret Splendor',
#   'authors': 'Sandra Brown',
#   'categories': 'Fiction'},
#  {'title': 'The Wild Swans', 'authors': 'Peg Kerr', 'categories': 'Fiction'},
#  {'title': 'Among the Dolls',
#   'authors': 'William Sleator',
#   'categories': 'Juvenile Fiction'},
#  {'title': "The Gunslinger's Bride",
#   'authors': 'Cheryl St. John',
#   'categories': 'Fiction'},
#  {'title': 'The Pronouncing Reading Book for Children, With an Intr., by W.L. Robinson',
#   'authors': 'William L Robinson',
#   'categories': 'History'},
#  {'title': 'Kitty and the Midnight Hour',
#   'authors': 'Carrie Vaughn',
#   'categories': 'Fiction'},
#  {'title': "He's Just Not That Into You (The Newly Expanded Edition)",
#   'authors': 'Greg Behrendt;Liz Tuccillo',
#   'categories': 'Family & Relationships'},
#  {'title': "If I Have a Wicked Stepmother, Where's My Prince?",
#   'authors': 'Melissa Kantor',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'The Quiet Little Woman',
#   'authors': 'Louisa May Alcott',
#   'categories': 'Fiction'},
#  {'title': 'Miracle on the 17th Green',
#   'authors': 'James Patterson;Peter De Jonge',
#   'categories': 'Fiction'},
#  {'title': 'Well of Darkness',
#   'authors': 'Margaret Weis;Tracy Hickman',
#   'categories': 'Fiction'},
#  {'title': 'Slightly Settled',
#   'authors': 'Wendy Markham',
#   'categories': 'Fiction'},
#  {'title': 'One L', 'authors': 'Scott Turow', 'categories': 'Law'},
#  {'title': 'Monkey Business',
#   'authors': 'Sarah Mlynowski',
#   'categories': 'Fiction'},
#  {'title': 'Madame Bovary',
#   'authors': 'Gustave Flaubert;Mildred Marmur',
#   'categories': 'Fiction'},
#  {'title': 'Captain Cat',
#   'authors': 'Syd Hoff',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Doom of the Darksword',
#   'authors': 'Margaret Weis',
#   'categories': 'Fiction'},
#  {'title': "Evelina, Or, The History of a Young Lady's Entrance Into the World",
#   'authors': 'Fanny Burney',
#   'categories': 'Fiction'},
#  {'title': 'Lights Out', 'authors': 'Peter Abrahams', 'categories': 'Fiction'},
#  {'title': 'Success', 'authors': 'Martin Amis', 'categories': 'Fiction'},
#  {'title': 'Oliver Twist',
#   'authors': 'Pauline Francis;Charles Dickens',
#   'categories': 'Juvenile Nonfiction'},
#  {'title': 'Charlie and the Great Glass Elevator',
#   'authors': 'Roald Dahl',
#   'categories': 'Adventure stories'},
#  {'title': 'Slowness', 'authors': 'Milan Kundera', 'categories': 'Fiction'},
#  {'title': 'Girls who Wore Black',
#   'authors': 'Ronna Johnson;Nancy McCampbell Grace',
#   'categories': 'Literary Criticism'},
#  {'title': 'Nightsword',
#   'authors': 'Margaret Weis;Tracy Hickman',
#   'categories': 'Fiction'},
#  {'title': "Hallowe'en Party",
#   'authors': 'Agatha Christie',
#   'categories': 'Poirot, Hercule (Fictitious character)'},
#  {'title': 'Early Candlelight',
#   'authors': 'Maud Hart Lovelace',
#   'categories': 'Fiction'},
#  {'title': 'Inside Job', 'authors': 'Connie Willis', 'categories': 'Fiction'},
#  {'title': 'Maggie, a Girl of the Streets, and Other Tales of New York',
#   'authors': 'Stephen Crane',
#   'categories': 'Fiction'},
#  {'title': 'Madame Bovary',
#   'authors': 'Gustave Flaubert;Geoffrey Wall',
#   'categories': 'Fiction'},
#  {'title': 'Solo', 'authors': 'Jill Mansell', 'categories': 'Chick lit'},
#  {'title': 'The Angry Hills', 'authors': 'Leon Uris', 'categories': 'Fiction'},
#  {'title': 'The Little House',
#   'authors': 'Philippa Gregory',
#   'categories': 'Country life'},
#  {'title': 'The People of Sparks',
#   'authors': 'Jeanne DuPrau',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Dark Water', 'authors': 'Linda Hall', 'categories': 'Fiction'},
#  {'title': 'Eaters of the Dead',
#   'authors': 'Michael Crichton',
#   'categories': 'Fiction'},
#  {'title': 'Spencerville',
#   'authors': 'Nelson DeMille',
#   'categories': 'Abused wives'},
#  {'title': 'A Meeting with Medusa',
#   'authors': 'Kim Stanley Robinson;Arthur Charles Clarke',
#   'categories': 'Fiction'},
#  {'title': 'The Confidence-man',
#   'authors': 'Herman Melville',
#   'categories': 'Literary Criticism'},
#  {'title': 'Women in Love',
#   'authors': 'D. H. Lawrence',
#   'categories': 'Fiction'},
#  {'title': "Edward Lear's Book of Nonsense",
#   'authors': 'Edward Lear',
#   'categories': 'Computers'},
#  {'title': 'Babbitt', 'authors': 'Sinclair Lewis', 'categories': 'Fiction'},
#  {'title': 'The Truelove Bride',
#   'authors': 'Shana Abé',
#   'categories': 'Fiction'},
#  {'title': "The Complete Idiot's Guide to World Religions",
#   'authors': 'Brandon Toropov;Luke Buckles',
#   'categories': 'Religion'},
#  {'title': 'The Secret Swan', 'authors': 'Shana Abé', 'categories': 'Fiction'},
#  {'title': 'The Foundations of Early Modern Europe, 1460-1559',
#   'authors': 'Eugene F. Rice;Anthony Grafton',
#   'categories': 'History'},
#  {'title': "Dragon's Gate",
#   'authors': 'Laurence Yep',
#   'categories': 'Juvenile Fiction'},
#  {'title': 'Next: The Future Just Happened',
#   'authors': 'Michael Lewis',
#   'categories': 'Business & Economics'},
#  {'title': 'Robinson Crusoe',
#   'authors': 'Daniel Defoe;Michael Shinagel',
#   'categories': 'Fiction'},
#  ...]

# %%
import nomic
nomic_apiKey = os.environ.get('NOMIC_API_KEY')
nomic.login(nomic_apiKey)
# Out:
#                                           Authenticate with the Nomic API
#                                          https://atlas.nomic.ai/cli-login
#                   Click the above link to retrieve your access token and then run `nomic login `
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 import nomic
#       2 nomic_apiKey = os.environ.get('NOMIC_API_KEY')
# ----> 3 nomic.login(nomic_apiKey)
#
# File c:\Users\mohamed.tawfik\AppData\Local\anaconda3\envs\openaienv\Lib\site-packages\nomic\cli.py:60, in login(token, tenant, domain)
#      54     console.print(auth0_auth_endpoint, style=style, justify="center")
#      55     console.print(
#      56         "Click the above link to retrieve your access token and then run `nomic login [token]`",
#      57         style=style,
#      58         justify="center",
#      59     )
# ---> 60     exit()
#      62 # save credential
#      63 if not nomic_base_path.exists():
#
# NameError: name 'exit' is not defined

# %%
embeddings = books['embedding'].to_list()
embeddings = np.array(embeddings)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mohamed.tawfik\AppData\Local\anaconda3\envs\openaienv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 5
#       1 embeddings = books['embedding'].to_list()
#       2 embeddings = np.array(embeddings)
# ----> 5 project = atlas.map_data(books, embeddings,description='Books')
#
# File c:\Users\mohamed.tawfik\AppData\Local\anaconda3\envs\openaienv\Lib\site-packages\nomic\atlas.py:94, in map_data(data, embeddings, identifier, description, id_field, is_public, indexed_field, projection, topic_model, duplicate_detection, embedding_model)
#      92         data = data.append_column(id_field, ids)  # type: ignore
#      93         added_id_field = True
# ---> 94     elif id_field not in data[0]:
#      95         raise ValueError("map_data data must be a list of dicts, a pandas dataframe, or a pyarrow table")
#      97 if added_id_field:
#
# File c:\Users\mohamed.tawfik\AppData\Local\anaconda3\envs\openaienv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\mohamed.tawfik\AppData\Local\anaconda3\envs\openaienv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0

# %%
# Build a map using the map_data method
dataset = atlas.map_data(data=books_dict,
                         embeddings=embeddings,
                          identifier='mabdelraza2/books-map',
                          description='A map for the books data.',
                          )
dataset.maps[0] # to view map build status
# Out:
# 2024-06-02 14:59:14.756 | INFO     | nomic.dataset:_create_project:918 - Creating dataset `books-map`
# 2024-06-02 14:59:15.660 | INFO     | nomic.atlas:map_data:110 - Uploading data to Atlas.
# 1it [00:03,  3.02s/it]
# 2024-06-02 14:59:18.706 | INFO     | nomic.dataset:_add_data:1597 - Upload succeeded.
# 2024-06-02 14:59:18.708 | INFO     | nomic.atlas:map_data:125 - `mabdelraza2/books-map`: Data upload succeeded to dataset`
# 2024-06-02 14:59:19.639 | WARNING  | nomic.dataset:create_index:1164 - You did not specify the `topic_label_field` option in your topic_model, your dataset will not contain auto-labeled topics.
# 2024-06-02 14:59:22.136 | INFO     | nomic.dataset:create_index:1301 - Created map `mabdelraza2/books-map` in dataset `mabdelraza2/books-map`: https://atlas.nomic.ai/data/mabdelraza2/books-map/map
# mabdelraza2/books-map: https://atlas.nomic.ai/data/mabdelraza2/books-map/map
